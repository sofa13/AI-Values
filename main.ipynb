# %% [markdown]
# # Setup

# %%
#from glove import Corpus, Glove

import numpy as np

#from nltk.stem import PorterStemmer
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
from nltk.stem.snowball import SnowballStemmer
from nltk import FreqDist

from sklearn.manifold import TSNE

import matplotlib.pyplot as plt

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='philsophie', api_key='BluoHvhy1CNCccyCOycW')

import gensim
from gensim.parsing.preprocessing import remove_stopwords

from scipy import spatial

from pprint import pprint

import scipy.cluster.hierarchy as hcluster

from TwitterAPI import TwitterAPI
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sophie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# C:\Users\Sophie\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning:
#
# detected Windows; aliasing chunkize to chunkize_serial

# %% [markdown]
# # Get user followings

# %%
#user = "jasonmillar"
user = "EricRWeinstein" # eric weinstein (800 followings)
#user = "lfountain6655" # 23 followings
tapi = TwitterAPI()

friends = tapi.getFollowings(user)
# Out:
# followings\EricRWeinstein-2019-09-01
# file exists

# %% [markdown]
# # Get user followings twitter URLs

# %%
acc_to_urls = tapi.getAccountsUrls(user, friends)
# Out:
# accounturls\EricRWeinstein-2019-09-01
# searchQuery: from:tabletmag filter:links
# Downloading max 500000000 tweets
# Downloaded 56 tweets
# 1164894236220755968
# No more tweets found
# searchQuery: from:RabbiWolpe filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1164802857322680320
# No more tweets found
# searchQuery: from:davereaboi filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167661580571619328
# Downloaded 200 tweets
# 1167105865561858050
# Downloaded 300 tweets
# 1166436943133102080
# Downloaded 400 tweets
# 1165853327701237760
# Downloaded 500 tweets
# 1165057009986736130
# Downloaded 554 tweets
# 1164835612928561153
# No more tweets found
# searchQuery: from:BretEastonEllis filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1165325929368784896
# No more tweets found
# searchQuery: from:Gauge_Trade filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:EpsilonTheory filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165285072477573120
# Downloaded 115 tweets
# 1164810512460238848
# No more tweets found
# searchQuery: from:berggruenInst filter:links
# Downloading max 500000000 tweets
# Downloaded 36 tweets
# 1164934154192072704
# No more tweets found
# searchQuery: from:NBerggruen filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1164982074815574016
# No more tweets found
# searchQuery: from:maureendowd filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1168194349047472129
# No more tweets found
# searchQuery: from:MM_Knight filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1167970911720333313
# No more tweets found
# searchQuery: from:PetitWTC filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:justicedems filter:links
# Downloading max 500000000 tweets
# Downloaded 47 tweets
# 1164893244444090369
# No more tweets found
# searchQuery: from:1971Film filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:MonicaLewinsky filter:links
# Downloading max 500000000 tweets
# Downloaded 24 tweets
# 1164879870301593600
# No more tweets found
# searchQuery: from:Madisonkanna filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1165795458750398464
# No more tweets found
# searchQuery: from:rickbeato filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165587941546221569
# No more tweets found
# searchQuery: from:hollymathnerd filter:links
# Downloading max 500000000 tweets
# Downloaded 19 tweets
# 1167550447206486021
# No more tweets found
# searchQuery: from:sandylocks filter:links
# Downloading max 500000000 tweets
# Downloaded 8 tweets
# 1165049559002832898
# No more tweets found
# searchQuery: from:roderickgraham filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1165035574996164610
# No more tweets found
# searchQuery: from:awilson_WLU filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1164997524215738368
# No more tweets found
# searchQuery: from:rjaraul filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:rosenstein filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:SchreiberUrs filter:links
# Downloading max 500000000 tweets
# Downloaded 44 tweets
# 1164838770690031616
# No more tweets found
# searchQuery: from:ChadTroutwine filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1165081466092474368
# No more tweets found
# searchQuery: from:jjforegon filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1166744716785934338
# No more tweets found
# searchQuery: from:davidblaine filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166705619006570496
# No more tweets found
# searchQuery: from:lexfridman filter:links
# Downloading max 500000000 tweets
# Downloaded 9 tweets
# 1164909805401718784
# No more tweets found
# searchQuery: from:AlinejadMasih filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165696919940866055
# Downloaded 113 tweets
# 1164901771321511936
# No more tweets found
# searchQuery: from:TitaniaMcGrath filter:links
# Downloading max 500000000 tweets
# Downloaded 15 tweets
# 1164879061849726976
# No more tweets found
# searchQuery: from:jlykken filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1164923933302259717
# No more tweets found
# searchQuery: from:gthooft filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:DavidDeutschOxf filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1165249089287720960
# No more tweets found
# searchQuery: from:visakanv filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167352545464897536
# Downloaded 200 tweets
# 1166724904860798981
# Downloaded 300 tweets
# 1165892515943174146
# Downloaded 400 tweets
# 1165438057664827392
# Downloaded 486 tweets
# 1164802515692449792
# No more tweets found
# searchQuery: from:Visit_St_Helena filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:Fly_Airlink filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166241820034129921
# No more tweets found
# searchQuery: from:helena_indy filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ConnectStHelena filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:MantisStHelena filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:SaintsDidNext filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1164819259823775750
# No more tweets found
# searchQuery: from:AndrewYang filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1164997729237389313
# Downloaded 107 tweets
# 1164870016061386752
# No more tweets found
# searchQuery: from:Martha_LMA filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1166019274814550016
# No more tweets found
# searchQuery: from:GazaSurfClub filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:NOAA_SOS filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:islandimagessth filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:KevinSpacey filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:loganabbott filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164933849987440640
# No more tweets found
# searchQuery: from:HiFromMichaelV filter:links
# Downloading max 500000000 tweets
# Downloaded 38 tweets
# 1165501139661574144
# No more tweets found
# searchQuery: from:alananewhouse filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:jockowillink filter:links
# Downloading max 500000000 tweets
# Downloaded 48 tweets
# 1164871427641630720
# No more tweets found
# searchQuery: from:belledejour_uk filter:links
# Downloading max 500000000 tweets
# Downloaded 40 tweets
# 1164994336829792256
# No more tweets found
# searchQuery: from:StHelenaHotels filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:The_Corres filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:missmayim filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1167084041176264705
# No more tweets found
# searchQuery: from:RalphNader filter:links
# Downloading max 500000000 tweets
# Downloaded 25 tweets
# 1165293828200443911
# No more tweets found
# searchQuery: from:JimHightower filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166008274686267392
# No more tweets found
# searchQuery: from:danielsheehan45 filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1166040405323988992
# No more tweets found
# searchQuery: from:RomeroInstitute filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1166046253840388096
# No more tweets found
# searchQuery: from:RickRubin filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1167473038356557827
# No more tweets found
# searchQuery: from:CharlotteKMuhl filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:jgreenhall filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:LilyCowles filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:jack filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1165634425104805888
# No more tweets found
# searchQuery: from:Vermeullarmine filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166424662668140544
# Downloaded 199 tweets
# 1164790063210758144
# No more tweets found
# searchQuery: from:KamalaHarris filter:links
# Downloading max 500000000 tweets
# Downloaded 59 tweets
# 1164937341078667264
# No more tweets found
# searchQuery: from:AOC filter:links
# Downloading max 500000000 tweets
# Downloaded 38 tweets
# 1165017102102646784
# No more tweets found
# searchQuery: from:KTmBoyle filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1165021087450767361
# No more tweets found
# searchQuery: from:KarenUhlenbeck filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:JoshLBarnett filter:links
# Downloading max 500000000 tweets
# Downloaded 52 tweets
# 1164945523842772993
# No more tweets found
# searchQuery: from:whereisdaz filter:links
# Downloading max 500000000 tweets
# Downloaded 84 tweets
# 1164808469293088776
# No more tweets found
# searchQuery: from:bryancallen filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166875934374289408
# No more tweets found
# searchQuery: from:newslaundry filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166176003535728640
# Downloaded 159 tweets
# 1164810518537752577
# No more tweets found
# searchQuery: from:cyrussaysin filter:links
# Downloading max 500000000 tweets
# Downloaded 15 tweets
# 1164850600007237632
# No more tweets found
# searchQuery: from:puliyabaazi filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1164841145865605120
# No more tweets found
# searchQuery: from:ThinkPragati filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164796384534384641
# No more tweets found
# searchQuery: from:DrHelenFisher filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:Gladwell filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1166037027713953792
# No more tweets found
# searchQuery: from:sambmd filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:UChicagoMag filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1165294445262266368
# No more tweets found
# searchQuery: from:kinglouiev22 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:TopGunner5 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:SusanObey22 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ShellMagel filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:BertrandCottage filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:martinreimann filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ShaylaEllick filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:rahaf84427714 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:Econ_n_Business filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ReaISatan filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:RashidaTlaib filter:links
# Downloading max 500000000 tweets
# Downloaded 29 tweets
# 1165033343097933826
# No more tweets found
# searchQuery: from:MZHemingway filter:links
# Downloading max 500000000 tweets
# Downloaded 64 tweets
# 1164884104166293505
# No more tweets found
# searchQuery: from:pewdiepie filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1165287951925960704
# No more tweets found
# searchQuery: from:Bar717 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:VossAndreae filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:jakepaul filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165489988802211843
# No more tweets found
# searchQuery: from:CathyTie filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:SethAbramson filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167098695701147648
# Downloaded 200 tweets
# 1165988961984176128
# Downloaded 254 tweets
# 1164791068233093120
# No more tweets found
# searchQuery: from:Kai_Lenny filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1166239832089096193
# No more tweets found
# searchQuery: from:miss9afi filter:links
# Downloading max 500000000 tweets
# Downloaded 65 tweets
# 1164932516429672451
# No more tweets found
# searchQuery: from:ilkkah filter:links
# Downloading max 500000000 tweets
# Downloaded 47 tweets
# 1164808605876404230
# No more tweets found
# searchQuery: from:DeirdreMcClosk filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:PamelaParesky filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165481440424935425
# Downloaded 112 tweets
# 1164866246434852864
# No more tweets found
# searchQuery: from:keikoinboston filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:NilesTopologist filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1166674053584891905
# No more tweets found
# searchQuery: from:lilmsragerr filter:links
# Downloading max 500000000 tweets
# Downloaded 44 tweets
# 1164957344901373952
# No more tweets found
# searchQuery: from:RationalBlonde filter:links
# Downloading max 500000000 tweets
# Downloaded 11 tweets
# 1164966752557645825
# No more tweets found
# searchQuery: from:johncarlosbaez filter:links
# Downloading max 500000000 tweets
# Downloaded 70 tweets
# 1164809020961509376
# No more tweets found
# searchQuery: from:DebMashekHxA filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:Ry_Nomad filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1165027499488743425
# No more tweets found
# searchQuery: from:MajorCBS filter:links
# Downloading max 500000000 tweets
# Downloaded 33 tweets
# 1164847497761587201
# No more tweets found
# searchQuery: from:JohnKirbow filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164871083935326208
# No more tweets found
# searchQuery: from:ThirdFactorMag filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164928098225274880
# No more tweets found
# searchQuery: from:InfinityJames filter:links
# Downloading max 500000000 tweets
# Downloaded 15 tweets
# 1164821541227384832
# No more tweets found
# searchQuery: from:Enterprise_ESH filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1167010298831745024
# No more tweets found
# searchQuery: from:StHelenaGovt filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:welovesthelena filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:sthelenafocus filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1167545937511817217
# No more tweets found
# searchQuery: from:sthelenatourism filter:links
# Downloading max 500000000 tweets
# Downloaded 15 tweets
# 1165687248949567491
# No more tweets found
# searchQuery: from:STHELENANEWS1 filter:links
# Downloading max 500000000 tweets
# Downloaded 47 tweets
# 1164914722136821760
# No more tweets found
# searchQuery: from:KUDOS_info filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166471981379870721
# No more tweets found
# searchQuery: from:AscensionPolice filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:tristancunhaRBX filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:lisahonan07 filter:links
# Downloading max 500000000 tweets
# Downloaded 18 tweets
# 1165997418556604416
# No more tweets found
# searchQuery: from:sburns61 filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1165322580368220160
# No more tweets found
# searchQuery: from:noUpside filter:links
# Downloading max 500000000 tweets
# Downloaded 28 tweets
# 1164944328935952386
# No more tweets found
# searchQuery: from:JeffDean filter:links
# Downloading max 500000000 tweets
# Downloaded 12 tweets
# 1165357166225776643
# No more tweets found
# searchQuery: from:maya_boyle filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1165716985294020608
# No more tweets found
# searchQuery: from:girlapproved_US filter:links
# Downloading max 500000000 tweets
# Downloaded 37 tweets
# 1164859611222093825
# No more tweets found
# searchQuery: from:dpakman filter:links
# Downloading max 500000000 tweets
# Downloaded 15 tweets
# 1165028772762046464
# No more tweets found
# searchQuery: from:harari_yuval filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1164790186334494721
# No more tweets found
# searchQuery: from:emergencetheory filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165038077531680768
# No more tweets found
# searchQuery: from:Pdx_resistance filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165850089635512320
# No more tweets found
# searchQuery: from:FarleyFilms filter:links
# Downloading max 500000000 tweets
# Downloaded 35 tweets
# 1165038684816625664
# No more tweets found
# searchQuery: from:AmericanAffrs filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1164944540584816641
# No more tweets found
# searchQuery: from:Loh filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167068573203697664
# Downloaded 200 tweets
# 1165516984114499584
# Downloaded 225 tweets
# 1164806689104658432
# No more tweets found
# searchQuery: from:GreggHurwitz filter:links
# Downloading max 500000000 tweets
# Downloaded 14 tweets
# 1164944019966713856
# No more tweets found
# searchQuery: from:datasociety filter:links
# Downloading max 500000000 tweets
# Downloaded 31 tweets
# 1164900599193694208
# No more tweets found
# searchQuery: from:beccalew filter:links
# Downloading max 500000000 tweets
# Downloaded 66 tweets
# 1164983823488016384
# No more tweets found
# searchQuery: from:hunchypoo filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1166136503937851392
# No more tweets found
# searchQuery: from:MrAndyNgo filter:links
# Downloading max 500000000 tweets
# Downloaded 18 tweets
# 1165359625685950469
# No more tweets found
# searchQuery: from:daxshepard filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166003034045812737
# No more tweets found
# searchQuery: from:meghan_daum filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1164886317853028352
# No more tweets found
# searchQuery: from:ZackOWeinstein filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:Zev__Weinstein filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:matloff filter:links
# Downloading max 500000000 tweets
# Downloaded 18 tweets
# 1164950843503730688
# No more tweets found
# searchQuery: from:Emmyjewel filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166209895013572608
# Downloaded 179 tweets
# 1164803734829879296
# No more tweets found
# searchQuery: from:donallogue filter:links
# Downloading max 500000000 tweets
# Downloaded 11 tweets
# 1165367047317938176
# No more tweets found
# searchQuery: from:CaitlinPacific filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166429815160705024
# Downloaded 164 tweets
# 1164791979235897344
# No more tweets found
# searchQuery: from:coldxman filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1165984589636087808
# No more tweets found
# searchQuery: from:3blue1brown filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1165317520133255168
# No more tweets found
# searchQuery: from:sarahjeong filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164956693584723968
# No more tweets found
# searchQuery: from:cjane87 filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166436243292512256
# Downloaded 175 tweets
# 1164875792712699904
# No more tweets found
# searchQuery: from:AJA_Cortes filter:links
# Downloading max 500000000 tweets
# Downloaded 99 tweets
# 1166290556353482752
# Downloaded 198 tweets
# 1164886319224578048
# No more tweets found
# searchQuery: from:rachpup85 filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1165944279585288192
# No more tweets found
# searchQuery: from:humansofny filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1164938528561569792
# No more tweets found
# searchQuery: from:z3nblack filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165017930477834245
# No more tweets found
# searchQuery: from:akirathedon filter:links
# Downloading max 500000000 tweets
# Downloaded 38 tweets
# 1164839451396194304
# No more tweets found
# searchQuery: from:XJester23 filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1164937171004010496
# No more tweets found
# searchQuery: from:raif_badawi filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1164932636546088964
# No more tweets found
# searchQuery: from:nickgillespie filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166023417394532352
# Downloaded 142 tweets
# 1164810132565319680
# No more tweets found
# searchQuery: from:madlee9 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:gargame58841686 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:_HelenDale filter:links
# Downloading max 500000000 tweets
# Downloaded 88 tweets
# 1164795566695436289
# No more tweets found
# searchQuery: from:TheStoicEmperor filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:labronhorton filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:kanyewest filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:SamoBurja filter:links
# Downloading max 500000000 tweets
# Downloaded 32 tweets
# 1164858663976284160
# No more tweets found
# searchQuery: from:OpenAI filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166443874258046976
# No more tweets found
# searchQuery: from:rjhaier filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1166705482423103489
# No more tweets found
# searchQuery: from:orbs_network filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165629795981496322
# No more tweets found
# searchQuery: from:urielpeled filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1165633774346035200
# No more tweets found
# searchQuery: from:Liv_Boeree filter:links
# Downloading max 500000000 tweets
# Downloaded 12 tweets
# 1164929515572908034
# No more tweets found
# searchQuery: from:glennbeck filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1164982857678360579
# No more tweets found
# searchQuery: from:epistemographer filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:conor64 filter:links
# Downloading max 500000000 tweets
# Downloaded 20 tweets
# 1164924039371976705
# No more tweets found
# searchQuery: from:sarahaustin filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166449105087819776
# No more tweets found
# searchQuery: from:cvaldary filter:links
# Downloading max 500000000 tweets
# Downloaded 17 tweets
# 1164912721487441920
# No more tweets found
# searchQuery: from:VitalikButerin filter:links
# Downloading max 500000000 tweets
# Downloaded 30 tweets
# 1164854002976206849
# No more tweets found
# searchQuery: from:nehabharti19 filter:links
# Downloading max 500000000 tweets
# Downloaded 20 tweets
# 1165120619521990657
# No more tweets found
# searchQuery: from:Barnes_Law filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167146839889461250
# Downloaded 200 tweets
# 1166070123582459904
# Downloaded 300 tweets
# 1165819502669398016
# Downloaded 400 tweets
# 1165044491419410432
# Downloaded 446 tweets
# 1164962082107772928
# No more tweets found
# searchQuery: from:itsSSR filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1164828662878724097
# No more tweets found
# searchQuery: from:erikverlinde filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:matt_siravo filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164985490929520640
# No more tweets found
# searchQuery: from:Noahpinion filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167606277658144769
# Downloaded 200 tweets
# 1167041995421843457
# Downloaded 300 tweets
# 1166385816425226240
# Downloaded 400 tweets
# 1165876568767361024
# Downloaded 500 tweets
# 1165289801601306624
# Downloaded 562 tweets
# 1164904619824148480
# No more tweets found
# searchQuery: from:NewWorldHominin filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165324171301158912
# No more tweets found
# searchQuery: from:DanielMiessler filter:links
# Downloading max 500000000 tweets
# Downloaded 21 tweets
# 1164938097446047744
# No more tweets found
# searchQuery: from:NickSzabo4 filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165839805520809984
# Downloaded 148 tweets
# 1164933742202245121
# No more tweets found
# searchQuery: from:webdevMason filter:links
# Downloading max 500000000 tweets
# Downloaded 48 tweets
# 1165055335448473600
# No more tweets found
# searchQuery: from:THErealDVORAK filter:links
# Downloading max 500000000 tweets
# Downloaded 80 tweets
# 1164808677271822337
# No more tweets found
# searchQuery: from:CharlieCarrel filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1166457948492771329
# No more tweets found
# searchQuery: from:nayafia filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166474560159371265
# No more tweets found
# searchQuery: from:michael_nielsen filter:links
# Downloading max 500000000 tweets
# Downloaded 32 tweets
# 1164980865807425536
# No more tweets found
# searchQuery: from:CarolinaEyck filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165222852649463808
# No more tweets found
# searchQuery: from:yaneerbaryam filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1164897935240433664
# No more tweets found
# searchQuery: from:LibertyRBlack filter:links
# Downloading max 500000000 tweets
# Downloaded 37 tweets
# 1164924490695839745
# No more tweets found
# searchQuery: from:pnjaban filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166459380541214720
# Downloaded 200 tweets
# 1164975237395431424
# Downloaded 210 tweets
# 1164934019840008192
# No more tweets found
# searchQuery: from:_vincentgallo filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:johnrobb filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1164948753196945408
# No more tweets found
# searchQuery: from:lizmstrategy filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ConceptualJames filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167562382450864128
# Downloaded 200 tweets
# 1166395726454239233
# Downloaded 300 tweets
# 1165052302207651840
# Downloaded 331 tweets
# 1164874969546985473
# No more tweets found
# searchQuery: from:Tmillerpoetry filter:links
# Downloading max 500000000 tweets
# Downloaded 17 tweets
# 1165331116393476096
# No more tweets found
# searchQuery: from:MiriamMakEnergy filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166113509194833923
# No more tweets found
# searchQuery: from:TheLaurenChen filter:links
# Downloading max 500000000 tweets
# Downloaded 42 tweets
# 1164971571842359301
# No more tweets found
# searchQuery: from:EstherPerel filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ChrisWillx filter:links
# Downloading max 500000000 tweets
# Downloaded 36 tweets
# 1164895074037239813
# No more tweets found
# searchQuery: from:lishali88 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:MsMelChen filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1166119250882367488
# No more tweets found
# searchQuery: from:laurakipnis filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1165005539568492544
# No more tweets found
# searchQuery: from:TheMullenMuhr filter:links
# Downloading max 500000000 tweets
# Downloaded 64 tweets
# 1165045809945010176
# No more tweets found
# searchQuery: from:RealCandaceO filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165311954828836866
# No more tweets found
# searchQuery: from:biruckx filter:links
# Downloading max 500000000 tweets
# Downloaded 25 tweets
# 1165694602877161472
# No more tweets found
# searchQuery: from:SexyIsntSexist filter:links
# Downloading max 500000000 tweets
# Downloaded 55 tweets
# 1164791581246754816
# No more tweets found
# searchQuery: from:SunnyLeone filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1164878900461223936
# No more tweets found
# searchQuery: from:DrDebraSoh filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:Quillette filter:links
# Downloading max 500000000 tweets
# Downloaded 97 tweets
# 1164845144991944705
# No more tweets found
# searchQuery: from:PardesSeleh filter:links
# Downloading max 500000000 tweets
# Downloaded 48 tweets
# 1164920529985396741
# No more tweets found
# searchQuery: from:waitbutwhy filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164982134265831425
# No more tweets found
# searchQuery: from:theQSLmind filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1167130992693391360
# No more tweets found
# searchQuery: from:Logo_Daedalus filter:links
# Downloading max 500000000 tweets
# Downloaded 95 tweets
# 1164996907585933312
# No more tweets found
# searchQuery: from:AsheSchow filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166480118992330753
# Downloaded 156 tweets
# 1164890610005921793
# No more tweets found
# searchQuery: from:unherd filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166749892901036035
# Downloaded 200 tweets
# 1164930531349487617
# Downloaded 209 tweets
# 1164786891410964480
# No more tweets found
# searchQuery: from:AwesomeKermit filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1168171492334436353
# No more tweets found
# searchQuery: from:LibertarianBlue filter:links
# Downloading max 500000000 tweets
# Downloaded 37 tweets
# 1164972729818390532
# No more tweets found
# searchQuery: from:mjaeckel filter:links
# Downloading max 500000000 tweets
# Downloaded 25 tweets
# 1164995778445795328
# No more tweets found
# searchQuery: from:JamesADamore filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ManohlaDargis filter:links
# Downloading max 500000000 tweets
# Downloaded 52 tweets
# 1164962260772515840
# No more tweets found
# searchQuery: from:JeffreyGoldberg filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165976970984919040
# Downloaded 135 tweets
# 1164826412487888899
# No more tweets found
# searchQuery: from:MarkSKrikorian filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165248654933975041
# Downloaded 118 tweets
# 1164868408074276870
# No more tweets found
# searchQuery: from:andrewklavan filter:links
# Downloading max 500000000 tweets
# Downloaded 42 tweets
# 1164974667397861376
# No more tweets found
# searchQuery: from:elizpingree filter:links
# Downloading max 500000000 tweets
# Downloaded 52 tweets
# 1164925320056778752
# No more tweets found
# searchQuery: from:jeremycarl4 filter:links
# Downloading max 500000000 tweets
# Downloaded 9 tweets
# 1164994049046188032
# No more tweets found
# searchQuery: from:Chadwick_Moore filter:links
# Downloading max 500000000 tweets
# Downloaded 60 tweets
# 1164917898223247362
# No more tweets found
# searchQuery: from:PalmerLuckey filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166585153612914689
# No more tweets found
# searchQuery: from:Jonathan_Blow filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1166468177536012288
# No more tweets found
# searchQuery: from:sapinker filter:links
# Downloading max 500000000 tweets
# Downloaded 33 tweets
# 1164918943766798337
# No more tweets found
# searchQuery: from:SavvyAuntie filter:links
# Downloading max 500000000 tweets
# Downloaded 18 tweets
# 1164957426665345024
# No more tweets found
# searchQuery: from:BenjaminABoyce filter:links
# Downloading max 500000000 tweets
# Downloaded 25 tweets
# 1165026934490685440
# No more tweets found
# searchQuery: from:PiaMalaney filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:clayroutledge filter:links
# Downloading max 500000000 tweets
# Downloaded 16 tweets
# 1164874576247042048
# No more tweets found
# searchQuery: from:bariweiss filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1164882040736665600
# No more tweets found
# searchQuery: from:Imamofpeace filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167017982792351744
# Downloaded 200 tweets
# 1165927915353034752
# Downloaded 300 tweets
# 1164883341251731456
# Downloaded 304 tweets
# 1164792398062350336
# No more tweets found
# searchQuery: from:gogreen18 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ChrisMilIington filter:links
# Downloading max 500000000 tweets
# Downloaded 33 tweets
# 1165293143706742786
# No more tweets found
# searchQuery: from:HdxAcademy filter:links
# Downloading max 500000000 tweets
# Downloaded 30 tweets
# 1164924408487731200
# No more tweets found
# searchQuery: from:stephstem filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1164880860090437638
# No more tweets found
# searchQuery: from:DrMANowak filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1164913809867386881
# No more tweets found
# searchQuery: from:Timcast filter:links
# Downloading max 500000000 tweets
# Downloaded 24 tweets
# 1164876150381916161
# No more tweets found
# searchQuery: from:YasMohammedxx filter:links
# Downloading max 500000000 tweets
# Downloaded 79 tweets
# 1164974998286565376
# No more tweets found
# searchQuery: from:scrowder filter:links
# Downloading max 500000000 tweets
# Downloaded 67 tweets
# 1164948825053618176
# No more tweets found
# searchQuery: from:IonaItalia filter:links
# Downloading max 500000000 tweets
# Downloaded 93 tweets
# 1165587594761113600
# No more tweets found
# searchQuery: from:HeatherEHeying filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:entprenr filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:greggutfeld filter:links
# Downloading max 500000000 tweets
# Downloaded 15 tweets
# 1165090829897216000
# No more tweets found
# searchQuery: from:DavidBCollum filter:links
# Downloading max 500000000 tweets
# Downloaded 91 tweets
# 1164865338724487168
# No more tweets found
# searchQuery: from:michaelshermer filter:links
# Downloading max 500000000 tweets
# Downloaded 27 tweets
# 1164959509883711488
# No more tweets found
# searchQuery: from:GlennLoury filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1167553781212561408
# No more tweets found
# searchQuery: from:razibkhan filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1165783834878599168
# No more tweets found
# searchQuery: from:amyalkon filter:links
# Downloading max 500000000 tweets
# Downloaded 85 tweets
# 1164919876604985344
# No more tweets found
# searchQuery: from:jordanbpeterson filter:links
# Downloading max 500000000 tweets
# Downloaded 16 tweets
# 1164972797329891331
# No more tweets found
# searchQuery: from:NAChristakis filter:links
# Downloading max 500000000 tweets
# Downloaded 87 tweets
# 1164879008611426304
# No more tweets found
# searchQuery: from:JDVance1 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:briankoppelman filter:links
# Downloading max 500000000 tweets
# Downloaded 32 tweets
# 1164890097814310912
# No more tweets found
# searchQuery: from:LouiseMensch filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165682528147185664
# Downloaded 143 tweets
# 1164915706238054401
# No more tweets found
# searchQuery: from:EliLake filter:links
# Downloading max 500000000 tweets
# Downloaded 52 tweets
# 1164941040253579265
# No more tweets found
# searchQuery: from:NatCounterPunch filter:links
# Downloading max 500000000 tweets
# Downloaded 77 tweets
# 1164956942734770177
# No more tweets found
# searchQuery: from:nfergus filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1165050337167724549
# No more tweets found
# searchQuery: from:HulkHogan filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1165650498172727302
# No more tweets found
# searchQuery: from:notaxation filter:links
# Downloading max 500000000 tweets
# Downloaded 61 tweets
# 1164957808422313984
# No more tweets found
# searchQuery: from:MannyCruz3 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:MAPS filter:links
# Downloading max 500000000 tweets
# Downloaded 12 tweets
# 1165035406166908928
# No more tweets found
# searchQuery: from:BeckleyResearch filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1164894810790146048
# No more tweets found
# searchQuery: from:stillgray filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167336065314615296
# Downloaded 200 tweets
# 1166874773915176965
# Downloaded 300 tweets
# 1166136474137321472
# Downloaded 400 tweets
# 1165643927027765249
# Downloaded 500 tweets
# 1165046501808099328
# Downloaded 540 tweets
# 1164786578721394689
# No more tweets found
# searchQuery: from:mirandadevine filter:links
# Downloading max 500000000 tweets
# Downloaded 50 tweets
# 1164879987712937984
# No more tweets found
# searchQuery: from:Mario_Livio filter:links
# Downloading max 500000000 tweets
# Downloaded 73 tweets
# 1164875350628810752
# No more tweets found
# searchQuery: from:fmanjoo filter:links
# Downloading max 500000000 tweets
# Downloaded 74 tweets
# 1164892280068571142
# No more tweets found
# searchQuery: from:clairlemon filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165852667400245248
# Downloaded 155 tweets
# 1164789764303667203
# No more tweets found
# searchQuery: from:DouglasCarswell filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166426028207693825
# Downloaded 171 tweets
# 1164796609181282304
# No more tweets found
# searchQuery: from:rightsduff filter:links
# Downloading max 500000000 tweets
# Downloaded 9 tweets
# 1164949805426249730
# No more tweets found
# searchQuery: from:richardcraib filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1166391384938438656
# No more tweets found
# searchQuery: from:eriktorenberg filter:links
# Downloading max 500000000 tweets
# Downloaded 11 tweets
# 1165445552009383936
# No more tweets found
# searchQuery: from:RubinReport filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1164922746708480000
# No more tweets found
# searchQuery: from:metamapps filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:WilliamAyers filter:links
# Downloading max 500000000 tweets
# Downloaded 11 tweets
# 1165048161037144070
# No more tweets found
# searchQuery: from:tylercowen filter:links
# Downloading max 500000000 tweets
# Downloaded 68 tweets
# 1164866758295085057
# No more tweets found
# searchQuery: from:Alicebentinck filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1166743238117658630
# No more tweets found
# searchQuery: from:matthewclifford filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164812576644980738
# No more tweets found
# searchQuery: from:Aflorini1 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:sorayadarabi filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1166675249896808449
# No more tweets found
# searchQuery: from:mlz filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:SamirNKhleif filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:JohnWRendon filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:campbell_brown filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:alanjosephwilli filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:allafarce filter:links
# Downloading max 500000000 tweets
# Downloaded 11 tweets
# 1164910299096526851
# No more tweets found
# searchQuery: from:Plinz filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:joshzepps filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1164823446410256386
# No more tweets found
# searchQuery: from:theNASciences filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1166062008166490114
# No more tweets found
# searchQuery: from:Marcia4Science filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1167133027039883268
# No more tweets found
# searchQuery: from:heather_berlin filter:links
# Downloading max 500000000 tweets
# Downloaded 8 tweets
# 1165572466732929024
# No more tweets found
# searchQuery: from:Swamy39 filter:links
# Downloading max 500000000 tweets
# Downloaded 79 tweets
# 1164856815261122565
# No more tweets found
# searchQuery: from:michellemalkin filter:links
# Downloading max 500000000 tweets
# Downloaded 93 tweets
# 1164934257447337984
# No more tweets found
# searchQuery: from:michaelbd filter:links
# Downloading max 500000000 tweets
# Downloaded 64 tweets
# 1164934178737184770
# No more tweets found
# searchQuery: from:JuliusKrein filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164928268832837632
# No more tweets found
# searchQuery: from:Ziya_Meral filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166976551830900736
# Downloaded 200 tweets
# 1166243147556491264
# Downloaded 262 tweets
# 1164792905812197376
# No more tweets found
# searchQuery: from:chaos_sonata filter:links
# Downloading max 500000000 tweets
# Downloaded 12 tweets
# 1164899252335546368
# No more tweets found
# searchQuery: from:PrometheusAM filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166742571957157888
# Downloaded 200 tweets
# 1165464251114217472
# Downloaded 209 tweets
# 1164794131131990017
# No more tweets found
# searchQuery: from:sainthelenainfo filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1165193997582835715
# No more tweets found
# searchQuery: from:erikbryn filter:links
# Downloading max 500000000 tweets
# Downloaded 66 tweets
# 1164849944840114176
# No more tweets found
# searchQuery: from:RichieCampbell filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1165348536172646400
# No more tweets found
# searchQuery: from:onambiguity filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:SeanWoods12 filter:links
# Downloading max 500000000 tweets
# Downloaded 19 tweets
# 1164905811912601601
# No more tweets found
# searchQuery: from:VoxVaughnuli filter:links
# Downloading max 500000000 tweets
# Downloaded 20 tweets
# 1164901699565154310
# No more tweets found
# searchQuery: from:Jason filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166022923032772609
# Downloaded 161 tweets
# 1164957006937149440
# No more tweets found
# searchQuery: from:primalpoly filter:links
# Downloading max 500000000 tweets
# Downloaded 42 tweets
# 1164911793782677510
# No more tweets found
# searchQuery: from:sjw_nonsense filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:JakeTurx filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166921329351757825
# No more tweets found
# searchQuery: from:FBI filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1164929132653875203
# No more tweets found
# searchQuery: from:DHSgov filter:links
# Downloading max 500000000 tweets
# Downloaded 85 tweets
# 1164927622700294145
# No more tweets found
# searchQuery: from:TuckerCarlson filter:links
# Downloading max 500000000 tweets
# Rate limit reached. Sleeping for: 690
# No more tweets found
# searchQuery: from:ChristopherA filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165729770673512449
# Downloaded 135 tweets
# 1165027510100221952
# No more tweets found
# searchQuery: from:benwerd filter:links
# Downloading max 500000000 tweets
# Downloaded 36 tweets
# 1164955231655874560
# No more tweets found
# searchQuery: from:dougyt filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166870425344860162
# No more tweets found
# searchQuery: from:antipcnyuprof filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1165011265393188867
# No more tweets found
# searchQuery: from:canarymission filter:links
# Downloading max 500000000 tweets
# Downloaded 38 tweets
# 1164885624303886337
# No more tweets found
# searchQuery: from:MotherJones filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167227273663123462
# Downloaded 200 tweets
# 1166761316062810113
# Downloaded 300 tweets
# 1166090122418429953
# Downloaded 400 tweets
# 1165088919425363973
# Downloaded 465 tweets
# 1164876159307440128
# No more tweets found
# searchQuery: from:seanmdav filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166409448782479361
# Downloaded 166 tweets
# 1164908008092176396
# No more tweets found
# searchQuery: from:lsarsour filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165697659308597253
# Downloaded 156 tweets
# 1164893863917641728
# No more tweets found
# searchQuery: from:POTUS filter:links
# Downloading max 500000000 tweets
# Downloaded 34 tweets
# 1165693401012068352
# No more tweets found
# searchQuery: from:DanBilzerian filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166274328113008641
# No more tweets found
# searchQuery: from:SenWarren filter:links
# Downloading max 500000000 tweets
# Downloaded 12 tweets
# 1166039004145475589
# No more tweets found
# searchQuery: from:adamdangelo filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:AlexEpstein filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1165270463418732544
# No more tweets found
# searchQuery: from:PeterScanavino filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1167107947073290240
# No more tweets found
# searchQuery: from:peterboghossian filter:links
# Downloading max 500000000 tweets
# Downloaded 19 tweets
# 1164938526737092608
# No more tweets found
# searchQuery: from:jackmurphylive filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166383841231155200
# Downloaded 200 tweets
# 1165019444780961794
# Downloaded 205 tweets
# 1164960217932730373
# No more tweets found
# searchQuery: from:rorysutherland filter:links
# Downloading max 500000000 tweets
# Downloaded 20 tweets
# 1164827802538872832
# No more tweets found
# searchQuery: from:Mauerback filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166368830874169345
# Downloaded 189 tweets
# 1164876849916383234
# No more tweets found
# searchQuery: from:apoorva_mehta filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:JohnDCook filter:links
# Downloading max 500000000 tweets
# Downloaded 18 tweets
# 1164885042008662017
# No more tweets found
# searchQuery: from:slatestarcodex filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:stranahan filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167159767384711168
# Downloaded 200 tweets
# 1165953052081365003
# Downloaded 266 tweets
# 1164869991923011585
# No more tweets found
# searchQuery: from:NMcCarthyPiano filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1165901193647972352
# No more tweets found
# searchQuery: from:DrDonVaughn filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:mattdusekwho filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:KeithOlbermann filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167625601831886849
# Downloaded 200 tweets
# 1167389056357060609
# Downloaded 300 tweets
# 1167002743162228736
# Downloaded 400 tweets
# 1166681660013854720
# Downloaded 500 tweets
# 1166247891264049153
# Downloaded 600 tweets
# 1165939592022962176
# Downloaded 700 tweets
# 1165251202407383040
# Downloaded 799 tweets
# 1164794456966516736
# No more tweets found
# searchQuery: from:NiceMangos filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166167613543800838
# Downloaded 113 tweets
# 1164858689267933184
# No more tweets found
# searchQuery: from:pbartstephens filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166713694216056835
# No more tweets found
# searchQuery: from:_TiffDamian filter:links
# Downloading max 500000000 tweets
# Downloaded 12 tweets
# 1165047041342496771
# No more tweets found
# ...
# Downloaded 5 tweets
# 1165217233322336256
# No more tweets found
# searchQuery: from:rkylesmith filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165411966036381697
# Downloaded 109 tweets
# 1164959636182773760
# No more tweets found
# searchQuery: from:finestructure filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:seanonolennon filter:links
# Downloading max 500000000 tweets
# Downloaded 8 tweets
# 1165039981762625541
# No more tweets found
# searchQuery: from:stevenstrogatz filter:links
# Downloading max 500000000 tweets
# Downloaded 75 tweets
# 1164957848113242113
# No more tweets found
# searchQuery: from:PeterDiamandis filter:links
# Downloading max 500000000 tweets
# Downloaded 16 tweets
# 1164963054305644545
# No more tweets found
# searchQuery: from:ChrisKantrowitz filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1166984127762972672
# No more tweets found
# searchQuery: from:carlystockdale filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:preskill filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164998952451575808
# No more tweets found
# searchQuery: from:A_Buchanan filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:aheineike filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:bradleyvoytek filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1166035936469078016
# No more tweets found
# searchQuery: from:curtischambers filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:love4excitement filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ThayerWalker filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:davidad filter:links
# Downloading max 500000000 tweets
# Downloaded 11 tweets
# 1167414397326778368
# No more tweets found
# searchQuery: from:Summit filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:chrislehmann filter:links
# Downloading max 500000000 tweets
# Downloaded 15 tweets
# 1165009182787084288
# No more tweets found
# searchQuery: from:NPDeMember filter:links
# Downloading max 500000000 tweets
# Downloaded 12 tweets
# 1165042965774909440
# No more tweets found
# searchQuery: from:davideagleman filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165356603555471360
# No more tweets found
# searchQuery: from:edfrenkel filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:jvonneumann filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:brianmcarney filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1165086862098255880
# No more tweets found
# searchQuery: from:petervan filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1165185552662040576
# No more tweets found
# searchQuery: from:Wildcat2030 filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:michaeljohng filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:researchremix filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:gvanrossum filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1165760672216403968
# No more tweets found
# searchQuery: from:poitevin filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1165283601350610945
# No more tweets found
# searchQuery: from:cgseife filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1166706214543273990
# No more tweets found
# searchQuery: from:LaurelKenner filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:nparmalee filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1164996961080139776
# No more tweets found
# searchQuery: from:GregoryJRader filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:CaptDavidRyan filter:links
# Downloading max 500000000 tweets
# Downloaded 18 tweets
# 1165469863458082816
# No more tweets found
# searchQuery: from:Epigenetique filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1166708644479733761
# No more tweets found
# searchQuery: from:lemire filter:links
# Downloading max 500000000 tweets
# Downloaded 15 tweets
# 1164963890624696320
# No more tweets found
# searchQuery: from:matteoluca filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166460026128621568
# No more tweets found
# searchQuery: from:Qrystal filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:leashless filter:links
# Downloading max 500000000 tweets
# Downloaded 90 tweets
# 1164954349006708738
# No more tweets found
# searchQuery: from:Summer_Ash filter:links
# Downloading max 500000000 tweets
# Downloaded 68 tweets
# 1164970697375879168
# No more tweets found
# searchQuery: from:sarawinge filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:AndreaKuszewski filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1164996130305789952
# No more tweets found
# searchQuery: from:CosmicEvolution filter:links
# Downloading max 500000000 tweets
# Downloaded 14 tweets
# 1165356191691595777
# No more tweets found
# searchQuery: from:TamarHaspel filter:links
# Downloading max 500000000 tweets
# Downloaded 41 tweets
# 1164957788839260160
# No more tweets found
# searchQuery: from:edraygoins filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1166150660557103104
# No more tweets found
# searchQuery: from:declanganley filter:links
# Downloading max 500000000 tweets
# Downloaded 92 tweets
# 1165206512014430208
# No more tweets found
# searchQuery: from:dscoughlin filter:links
# Downloading max 500000000 tweets
# Downloaded 19 tweets
# 1165075212787953664
# No more tweets found
# searchQuery: from:mattmight filter:links
# Downloading max 500000000 tweets
# Downloaded 22 tweets
# 1164967355295735808
# No more tweets found
# searchQuery: from:Jeff_Gomez filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1164962232305901569
# No more tweets found
# searchQuery: from:wikileaks filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166081362958409728
# No more tweets found
# searchQuery: from:SergioTarrero filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:chickelit filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1166886503546413056
# No more tweets found
# searchQuery: from:arsphysica filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ericmjohnson filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166422717244964864
# No more tweets found
# searchQuery: from:sciencegoddess filter:links
# Downloading max 500000000 tweets
# Downloaded 20 tweets
# 1165101557244936193
# No more tweets found
# searchQuery: from:ddblane filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1165887699250819072
# No more tweets found
# searchQuery: from:JoshRosenau filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165667230383857664
# Downloaded 117 tweets
# 1165039827542335488
# No more tweets found
# searchQuery: from:GregBoustead filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1166406697201623041
# No more tweets found
# searchQuery: from:gravana filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1166649449059422210
# No more tweets found
# searchQuery: from:erigentry filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:sebpaquet filter:links
# Downloading max 500000000 tweets
# Downloaded 7 tweets
# 1165776368371687427
# No more tweets found
# searchQuery: from:RogerHighfield filter:links
# Downloading max 500000000 tweets
# Downloaded 80 tweets
# 1165156513243115520
# No more tweets found
# searchQuery: from:unclenate filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1164992685028962304
# No more tweets found
# searchQuery: from:monstro filter:links
# Downloading max 500000000 tweets
# Downloaded 5 tweets
# 1165622505186324480
# No more tweets found
# searchQuery: from:hmason filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1164985050334670849
# No more tweets found
# searchQuery: from:VenessaMiemis filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:hackingdata filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:INETeconomics filter:links
# Downloading max 500000000 tweets
# Downloaded 16 tweets
# 1164998242322374656
# No more tweets found
# searchQuery: from:pgirvan filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1164996302117191681
# No more tweets found
# searchQuery: from:queuecoon filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:mathheadinc filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:CatoInstitute filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166069812042358784
# Downloaded 149 tweets
# 1164982642858758145
# No more tweets found
# searchQuery: from:ideasurge filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165335461734170624
# Downloaded 107 tweets
# 1165108950720638976
# No more tweets found
# searchQuery: from:decohere filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:MoMath1 filter:links
# Downloading max 500000000 tweets
# Downloaded 8 tweets
# 1166020853395591169
# No more tweets found
# searchQuery: from:JohnAllenPaulos filter:links
# Downloading max 500000000 tweets
# Downloaded 37 tweets
# 1164954427301736448
# No more tweets found
# searchQuery: from:stevesilberman filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1166494689148600320
# Downloaded 200 tweets
# 1164958208747700224
# No more tweets found
# searchQuery: from:sumrtime filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:christineottery filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:AndreiaASoares filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:tttabata filter:links
# Downloading max 500000000 tweets
# Downloaded 21 tweets
# 1165526731802824704
# No more tweets found
# searchQuery: from:IBJIYONGI filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167516007902191617
# Downloaded 200 tweets
# 1167037275735281664
# Downloaded 300 tweets
# 1166453964373708800
# Downloaded 400 tweets
# 1165804263337070593
# Downloaded 472 tweets
# 1165254219051483137
# No more tweets found
# searchQuery: from:rvidal filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:conorjh filter:links
# Downloading max 500000000 tweets
# Downloaded 14 tweets
# 1165018071599386626
# No more tweets found
# searchQuery: from:maggiekb1 filter:links
# Downloading max 500000000 tweets
# Downloaded 19 tweets
# 1165530481904930817
# No more tweets found
# searchQuery: from:astrolisa filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1164977537115729920
# No more tweets found
# searchQuery: from:evgenymorozov filter:links
# Downloading max 500000000 tweets
# Downloaded 40 tweets
# 1164963095669874690
# No more tweets found
# searchQuery: from:robertghrist filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1165070009888116741
# No more tweets found
# searchQuery: from:laura_greenaura filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1167903099492564992
# Downloaded 200 tweets
# 1167314436048052224
# Downloaded 259 tweets
# 1165036294990368768
# No more tweets found
# searchQuery: from:gomberoff filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1165633033237598210
# No more tweets found
# searchQuery: from:matthewherper filter:links
# Downloading max 500000000 tweets
# Downloaded 96 tweets
# 1164956763747168257
# No more tweets found
# searchQuery: from:edge filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:ubfid filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:NatureNews filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165640017080983553
# Downloaded 119 tweets
# 1164964282213310466
# No more tweets found
# searchQuery: from:peterrowlett filter:links
# Downloading max 500000000 tweets
# Downloaded 23 tweets
# 1165318678293962753
# No more tweets found
# searchQuery: from:shefaly filter:links
# Downloading max 500000000 tweets
# Downloaded 34 tweets
# 1165143251533389824
# No more tweets found
# searchQuery: from:RadioKate filter:links
# Downloading max 500000000 tweets
# Downloaded 8 tweets
# 1165628192037715970
# No more tweets found
# searchQuery: from:TJ_Kelleher filter:links
# Downloading max 500000000 tweets
# Downloaded 10 tweets
# 1165469510855532544
# No more tweets found
# searchQuery: from:sc_k filter:links
# Downloading max 500000000 tweets
# Downloaded 9 tweets
# 1165234123478372353
# No more tweets found
# searchQuery: from:johnlogsdon filter:links
# Downloading max 500000000 tweets
# Downloaded 8 tweets
# 1166000854190776320
# No more tweets found
# searchQuery: from:BretWeinstein filter:links
# Downloading max 500000000 tweets
# Downloaded 6 tweets
# 1165328200815104000
# No more tweets found
# searchQuery: from:grahamfarmelo filter:links
# Downloading max 500000000 tweets
# Rate limit reached. Sleeping for: 702
# Downloaded 54 tweets
# 1165134339199447040
# No more tweets found
# searchQuery: from:maverickmath filter:links
# Downloading max 500000000 tweets
# Downloaded 4 tweets
# 1165755044714749959
# No more tweets found
# searchQuery: from:mathpunk filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1165032587674488833
# No more tweets found
# searchQuery: from:unlearnedhands filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:Gelada filter:links
# Downloading max 500000000 tweets
# Downloaded 13 tweets
# 1165071801250189313
# No more tweets found
# searchQuery: from:LeeBillings filter:links
# Downloading max 500000000 tweets
# Downloaded 26 tweets
# 1165399041217376257
# No more tweets found
# searchQuery: from:TEDJohnMark filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1167813741104250880
# No more tweets found
# searchQuery: from:holdenweb filter:links
# Downloading max 500000000 tweets
# Downloaded 100 tweets
# 1165338614596812800
# Downloaded 129 tweets
# 1164956109662281728
# No more tweets found
# searchQuery: from:FQXi filter:links
# Downloading max 500000000 tweets
# Downloaded 60 tweets
# 1165255486628868096
# No more tweets found
# searchQuery: from:orzelc filter:links
# Downloading max 500000000 tweets
# Downloaded 83 tweets
# 1164958520921534466
# No more tweets found
# searchQuery: from:akarshsimha filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:pwang filter:links
# Downloading max 500000000 tweets
# Downloaded 38 tweets
# 1164961733947068416
# No more tweets found
# searchQuery: from:materion filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:CameronNeylon filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1166616917219717121
# No more tweets found
# searchQuery: from:mattleifer filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:dabacon filter:links
# Downloading max 500000000 tweets
# Downloaded 11 tweets
# 1165625967898816512
# No more tweets found
# searchQuery: from:ahaspel filter:links
# Downloading max 500000000 tweets
# Downloaded 1 tweets
# 1167539143431397383
# No more tweets found
# searchQuery: from:askpang filter:links
# Downloading max 500000000 tweets
# Downloaded 28 tweets
# 1164990398407725056
# No more tweets found
# searchQuery: from:MarcusduSautoy filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:riemannzeta filter:links
# Downloading max 500000000 tweets
# Downloaded 3 tweets
# 1165411708560527360
# No more tweets found
# searchQuery: from:garrettlisi filter:links
# Downloading max 500000000 tweets
# Downloaded 2 tweets
# 1165083323774861312
# No more tweets found
# searchQuery: from:d_allison filter:links
# Downloading max 500000000 tweets
# No more tweets found
# searchQuery: from:skdh filter:links
# Downloading max 500000000 tweets
# Downloaded 49 tweets
# 1165128272092508160
# No more tweets found

# %% [markdown]
# # Read files

# %%
embeddings_index = {}
glove_file = './glove.6B/glove.6B.300d.txt'

with open(glove_file, "r", encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
#print(embeddings_index['abundance'])

# %%
with open("values.txt", "r", encoding='utf-8') as fin:
    values = fin.readlines()

values = [x.strip().lower() for x in values] 
len(values)
# Out:
# 483

# %%
texts = []
with open("titles.txt", "r", encoding='utf-8') as fin:
    for line in fin:
        line = remove_stopwords(line)
        texts.append(gensim.utils.simple_preprocess(line))

len(texts)
# Out:
# 48

# %%
texts = []
with open("./Tweepy/twitter_ethics_text", "r", encoding='utf-8') as fin:
    twitter_ethics = eval(fin.read())
    for line in twitter_ethics:
        line = remove_stopwords(line)
        texts.append(gensim.utils.simple_preprocess(line))

len(texts)
# Out:
# 307

# %%
print(texts)
# Out:
# [['how', 'th', 'century', 'fox', 'uses', 'ml', 'predict', 'movie', 'audience', 'google', 'cloud', 'blog'], ['facebook', 'clear', 'history', 'tool', 'actually', 'happen', 'it', 'time'], ['why', 'mass', 'data', 'fragmentation', 'matters', 'compare', 'cloud'], ['opinion', 'the', 'two', 'codes', 'your', 'kids', 'need', 'know', 'the', 'new', 'york', 'times'], ['bloomberg', 'are', 'robot'], ['samsung', 'announces', 'new', 'galaxy', 'plus', 'phones', 'business', 'insider'], ['silicon', 'valley', 'oversight', 'democrats', 'probe', 'tech', 'privacy', 'practices', 'the', 'washington', 'post'], ['facebook', 'cryptocurrency', 'whatsapp', 'launch', 'half', 'report', 'business', 'insider'], ['sophie', 'thiebaut', 'linkedin', 'wil', 'je', 'meer', 'weten', 'ubo', 'en', 'digitaal', 'schrijf', 'je', 'voor', 'het', 'webinar', 'van', 'corporify'], ['tolkien', 'official', 'trailer', 'fox', 'searchlight', 'youtube'], ['new', 'flaws', 'allow', 'attackers', 'intercept', 'calls', 'track', 'phone', 'locations', 'techcrunch'], ['priestley', 'time', 'plays', 'wikipedia'], ['israeli', 'moon', 'mission', 'spaceil', 'successfully', 'launches', 'spacex', 'rocket', 'business', 'insider'], ['automating', 'creativity', 'why', 'short', 'talk', 'samim', 'youtube'], ['tesla', 'closing', 'stores', 'means', 'layoffs', 'retail', 'employees', 'business', 'insider'], ['interesting', 'practical', 'amazon', 'purchases', 'business', 'insider'], ['fitbit', 'sees', 'current', 'quarter', 'revenue', 'estimates', 'business', 'insider'], ['google', 'announced', 'end', 'forced', 'arbitration', 'internal', 'matters', 'business', 'insider'], ['purchases', 'wish', 'told', 'apartment', 'business', 'insider'], ['darpa', 'thinks', 'ai', 'could', 'help', 'troops', 'telepathically', 'control', 'machines', 'defense', 'one'], ['chinese', 'company', 'leaves', 'muslim', 'tracking', 'facial', 'recognition', 'database', 'exposed', 'online', 'zdnet'], ['network', 'centric', 'warfare', 'wikipedia'], ['graham', 'spencer', 'programming', 'the', 'internet', 'public', 'lecture', 'youtube'], ['when', 'kids', 'google', 'themselves', 'the', 'atlantic'], ['is', 'drive', 'by', 'sex', 'toy', 'hacking', 'wake', 'up', 'britain', 'internet', 'security', 'chi', 'onwurah', 'opinion', 'the', 'guardian'], ['bob', 'marley', 'could', 'loved', 'lyrics', 'youtube'], ['cpdp', 'profiling', 'microtargeting', 'right', 'reasonable', 'algorithmic', 'inferences', 'youtube'], ['artificial', 'intelligence', 'describing', 'smells', 'ibm', 'research', 'quartz'], ['apple', 'release', 'new', 'ipod', 'business', 'insider'], ['travel', 'essentials', 'reduce', 'stress', 'away', 'suitcase', 'clear', 'membership', 'business', 'insider'], ['audi', 'cars', 'tell', 'you', 'how', 'fast', 'go', 'catch', 'all', 'green', 'lights', 'wired'], ['you', 'give', 'apps', 'sensitive', 'personal', 'information', 'then', 'they', 'tell', 'facebook', 'wsj'], ['what', 'happens', 'younger', 'workers', 'when', 'older', 'workers', 'don', 'retire'], ['paid', 'family', 'leave', 'investment', 'public', 'health', 'handout'], ['sciencedirect'], ['what', 'is', 'public', 'the', 'message', 'medium'], ['medical', 'it', 'must', 'boost', 'its', 'immune', 'system', 'compare', 'cloud'], ['ai', 'won', 'relieve', 'misery', 'facebook', 'human', 'moderators', 'the', 'verge'], ['data', 'new', 'oil', 'adam', 'schlosser', 'world', 'economic', 'forum', 'business', 'insider'], ['machine', 'learning', 'contributing', 'reproducibility', 'crisis', 'science', 'mit', 'technology', 'review'], ['the', 'soothing', 'promise', 'our', 'own', 'artisanal', 'internet', 'wired'], ['hidden', 'patterns', 'inside', 'fruits', 'vegetables', 'youtube'], ['billion', 'video', 'conferencing', 'company', 'zoom', 'aiming', 'april', 'ipo', 'business', 'insider'], ['hbo', 'ceo', 'richard', 'plepler', 'leaving', 'nearly', 'years', 'business', 'insider'], ['how', 'to', 'leverage', 'artificial', 'intelligence', 'to', 'gain', 'business', 'advantage'], ['revealed', 'gambling', 'industry', 'targets', 'poor', ' ...

# %%
remove_words = {"https", "co", "business", "insider", "youtube", "the", "how", "why", "what", "why", "times", "medium", "techcrunch", "in", "for", "are", "is", "it", "new", "york", "times", "we", "venturebeat", "to", "when", "wired", "verge", "your", "than", "you"}

# %%
for text in texts:
    for word in text:
        if(word in remove_words):
            text.remove(word)
            #print(word)

# %%
f_texts = []
for w in texts:
    f_texts += w
len(f_texts)
# Out:
# 2048

# %%
f_sen = ' '.join(f_texts)

# %%
f_token = word_tokenize(f_sen)

# %%
fdist = FreqDist(f_token)

# print out words only (without counts and weights)
print(fdist.most_common(50))
# Out:
# [('ai', 27), ('cloud', 22), ('data', 20), ('google', 19), ('samsung', 11), ('galaxy', 11), ('world', 10), ('facebook', 9), ('review', 9), ('compare', 8), ('intelligence', 8), ('apple', 8), ('ethical', 8), ('tech', 7), ('artificial', 7), ('learning', 7), ('news', 7), ('times', 6), ('official', 6), ('amazon', 6), ('guardian', 6), ('technology', 6), ('fold', 6), ('women', 6), ('china', 6), ('price', 6), ('digital', 6), ('chart', 6), ('post', 5), ('phone', 5), ('wikipedia', 5), ('internet', 5), ('release', 5), ('science', 5), ('video', 5), ('twitter', 5), ('instagram', 5), ('statista', 5), ('kids', 4), ('robot', 4), ('linkedin', 4), ('tesla', 4), ('could', 4), ('help', 4), ('human', 4), ('economic', 4), ('date', 4), ('use', 4), ('watch', 4), ('future', 4)]

# %% [markdown]
# # Helper functions

# %%
def plotplotly(X, y, text=False):
    mode = 'markers'
    if text:
        mode = 'markers+text'
        
    data = [
    go.Scatter(
        x=X[:, 0],
        y=X[:, 1],
        mode=mode,
        text=y
        )
    ]

    layout = go.Layout(title='Hover over the points to see the text')

    fig = go.Figure(data=data, layout=layout)
    return fig

# %%
def hashdictkey(key):
    return str(list(key))

# %%
def unhashdictkey(key, asnparray=True):
    if asnparray:
        return np.array(eval(key))
    return eval(key)

# %%
def getDistance(list1, list2):
    return spatial.distance.cosine(list1, list2)

# %%
def compileMatrix(comparelist):
    """
    Given a list of vectors, this method returns a matrix of pairwise comparison calculations of distances
    :param tree_list: list of trees in bracket notation
    :return: matrix of pairwise comparisons using distance
    """

    print("# comparelist:", len(comparelist))

    n = len(comparelist)
    print("# n: ", n)
    disMatrix = [x[:] for x in [[0] * n] * n]
    #threshold = 0.32

    for i in range(n - 1):
        for j in range(i + 1, n):
            list1 = comparelist[i]
            list2 = comparelist[j]

            # thresholds
            
            # distance
            dis = getDistance(list1, list2)

            # update matrix
            disMatrix[i][j] = disMatrix[j][i] = dis
    
    return disMatrix

# %%
def embcomb(embs, words, min_comb=2, max_comb=3):
    emb_comb = []
    word_comb = []
    if len(embs) < min_comb:
        return None
    for i in range(len(embs)+1):
        for j in range(i+2, min(len(embs)+1, i+max_comb+1)):
            #print(i, j)
            #print(embs[i:j,:])
            #print(y[i:j])
            ec = np.mean((embs[i:j,:]), axis=0)
            emb_comb.append(ec)
            word_comb.append(set(y[i:j]))
    return [emb_comb, word_comb]

# %%
def thresholdMatrix(disMatrix, threshold=0.2, num_threshold=4):
    """
    Given a matrix, method returns which rows indexes have columns less than a certain threshold at least a certain number of times
    :param disMatrix: a matrix of distances
    :param threshold: the columns in a row to be thresholded
    :param num_threshold: the number of columns with a certain threshold
    :return: vector of row indexes
    """

    print("# disMatrix:", len(disMatrix))

    n = len(disMatrix)
    print("# n ", n)
    
    disThresholded = []
    for i in range(n - 1):
        cnt = 0
        for j in range(i + 1, n):

            # distance
            dis = disMatrix[i][j]
            
            if dis < threshold:
                cnt += 1
                
        disThresholded.append(cnt)
    
    idxs = [i for i, cnt in enumerate(disThresholded) if cnt >= num_threshold]
    
    return idxs

# %%
def getMatrixClusters(disMatrix, threshold=0.2, num_threshold=4):
    """
    Given a matrix, method returns an array of clustered terms that are similar enough by a threshold have at least a certain number of terms
    :param disMatrix: a matrix of distances
    :param threshold: the columns in a row to be thresholded
    :param num_threshold: the number of columns with a certain threshold
    :return: set of clusters
    """

    print("# disMatrix:", len(disMatrix))

    n = len(disMatrix)
    print("# n ", n)
    
    clusters = set()
    for i in range(n - 1):
        clu = set()
        cnt = 0
        for j in range(i + 1, n):

            # distance
            dis = disMatrix[i][j]
            
            if dis < threshold:
                clu.add(j)
        
        clu = frozenset(clu)
        clusters.add(clu)
    
    print(len(clusters))
    
    clusters_thresholded = set()
    for cluster in clusters:
        if len(cluster) >= num_threshold:
            clusters_thresholded.add(cluster)
                
    return clusters_thresholded

# %% [markdown]
# # Values analysis

# %%
X = np.array([embeddings_index[x] for x in values if x in embeddings_index])
y = np.array([x for x in values if x in embeddings_index])
len(X)
# Out:
# 455

# %%
X_embedded = TSNE(n_components=2, perplexity=40, verbose=0).fit_transform(X)

# %%
plt.scatter(X_embedded[:, 0], X_embedded[:, 1])

# %%
fig = plotplotly(X_embedded, y, text=True)
py.iplot(fig, filename='hover-chart-basic')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~philsophie/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # From twitter article titles, find terms in title most similar to AI-Value list (threshold), then rank the AI-Value most mentioned with article titles

# %%
# get value vectors
X_value = np.array([embeddings_index[x] for x in values if x in embeddings_index])
y_value = np.array([x for x in values if x in embeddings_index])
len(X_value)
# Out:
# 455

# %%
# get word vectors for each article title
value_mentions = dict()
threshold = 0.4
ignore_word = set()
for title in texts:
    min_idxs = []
    words = []
    for word in title:
        ignore = True
        if word in embeddings_index and word not in ignore_word:
            word_vec = embeddings_index[word]
            for i, x_v in enumerate(X_value):
                # check similarity is less than threshold
                dist = getDistance(word_vec, x_v)
                if dist < threshold:
                    min_idxs.append([i, word])
                    ignore = False
            if ignore:
                # add word to set
                ignore_word.add(word)
    
    # add values
    for ent in min_idxs:
        min_idx, word = ent
        value_key = y_value[min_idx]
        if value_key not in value_mentions:
            value_mentions[value_key] = dict()
            value_mentions[value_key]["count"] = 0
            value_mentions[value_key]["sim_words"] = []
            value_mentions[value_key]["titles"] = []
        
        value_mentions[value_key]["count"] += 1
        value_mentions[value_key]["sim_words"].append(word)
        value_mentions[value_key]["titles"].append('-'.join(title))
        
print(len(value_mentions))
# Out:
# 78

# %%
pprint(value_mentions)
# Out:
# {'accomplishment': {'count': 1,
#                     'sim_words': ['remarkable'],
#                     'titles': ['for-black-history-month-remarkable-women-men-we-overlooked-since-the-new-york-times']},
#  'accountability': {'count': 1,
#                     'sim_words': ['oversight'],
#                     'titles': ['silicon-valley-oversight-democrats-probe-tech-privacy-practices-the-washington-post']},
#  'art': {'count': 1,
#          'sim_words': ['artist'],
#          'titles': ['ted-nelson-artist-philosopher-filmmaker-new-media-pioneer-youtube']},
#  'care': {'count': 3,
#           'sim_words': ['health', 'medical', 'health'],
#           'titles': ['paid-family-leave-investment-public-health-handout',
#                      'medical-it-must-boost-its-immune-system-compare-cloud',
#                      'health-fitness-startups-boom-business-insider']},
#  'challenge': {'count': 4,
#                'sim_words': ['challenges',
#                              'challenges',
#                              'challenges',
#                              'challenge'],
#                'titles': ['at-think-ibm-brings-ai-multicloud-confronts-formidable-challenges-siliconangle',
#                           'the-folly-trolleys-ethical-challenges-autonomous-vehicles',
#                           'the-folly-trolleys-ethical-challenges-autonomous-vehicles',
#                           'challenge-chart-js-starter-app-youtube']},
#  'change': {'count': 3,
#             'sim_words': ['need', 'changing', 'change'],
#             'titles': ['opinion-the-two-codes-your-kids-need-know-the-new-york-times',
#                        'explaining-parochialism-causal-account-political-polarization-changing-economic-environments',
#                        'intelligence-officials-warn-climate-change-is-worldwide-threat-insideclimate-news']},
#  'commitment': {'count': 1,
#                 'sim_words': ['promise'],
#                 'titles': ['the-soothing-promise-our-own-artisanal-internet-wired']},
#  'competition': {'count': 2,
#                  'sim_words': ['competitive', 'compete'],
#                  'titles': ['blockchain-adopting-legal-frameworks-gain-competitive-advantage',
#                             'apple-can-compete-samsung-galaxy-fold-goldman-sachs-says-business-insider']},
#  'completion': {'count': 1,
#                 'sim_words': ['completed'],
#                 'titles': ['google-completed-ethical-reviews-ai-projects-products-deals-venturebeat']},
#  'control': {'count': 2,
#              'sim_words': ['control', 'controlled'],
#              'titles': ['darpa-thinks-ai-could-help-troops-telepathically-control-machines-defense-one',
#                         'stanford-researchers-develop-brain-controlled-typing-people-paralysis-youtube']},
#  'cooperation': {'count': 2,
#                  'sim_words': ['cooperation', 'countries'],
#                  'titles': ['prepared-for-partnership-trust-distrust-international-cooperation',
#                             'how-green-new-deal-exploit-developing-countries']},
#  'coordination': {'count': 1,
#                   'sim_words': ['cooperation'],
#                   'titles': ['prepared-for-partnership-trust-distrust-international-cooperation']},
#  'country': {'count': 1,
#              'sim_words': ['countries'],
#              'titles': ['how-green-new-deal-exploit-developing-countries']},
#  'creativity': {'count': 4,
#                 'sim_words': ['creativity',
#                               'innovation',
#                               'creative',
#                               'innovation'],
#                 'titles': ['automating-creativity-why-short-talk-samim-youtube',
#                            'google-created-responsible-innovation-team-check-ai-ethical-quartz',
#                            'creative-candidate-sourcing-strategies-ikea-spotify-deloitte-hire-google',
#                            'worried-about-bias-ai-worry-about-humans-instead-center-data-innovation']},
#  'desire': {'count': 1,
#             'sim_words': ['wish'],
#             'titles': ['purchases-wish-told-apartment-business-insider']},
#  'discovery': {'count': 1,
#                'sim_words': ['discovery'],
#                'titles': ['discovery-cameras-built-airlines-seats-sparks-privacy-concerns-the-verge']},
#  'drive': {'count': 2,
#            'sim_words': ['drive', 'drive'],
#            'titles': ['is-drive-by-sex-toy-hacking-wake-up-britain-internet-security-chi-onwurah-opinion-the-guardian',
#                       'council-post-how-to-foster-positive-employee-experiences-to-drive-long-term-digital-transformations']},
#  'economy': {'count': 4,
#              'sim_words': ['economic', 'economic', 'economic', 'economic'],
#              'titles': ['data-new-oil-adam-schlosser-world-economic-forum-business-insider',
#                         'this-happen-natural-world-insects-disappeared-world-economic-forum',
#                         'explaining-parochialism-causal-account-political-polarization-changing-economic-environments',
#                         'the-new-geopolitics-artificial-intelligence-world-economic-forum']},
#  'education': {'count': 2,
#                'sim_words': ['health', 'health'],
#                'titles': ['paid-family-leave-investment-public-health-handout',
#                           'health-fitness-startups-boom-business-insider']},
#  'environment': {'count': 3,
#                  'sim_words': ['environments', 'climate', 'environment'],
#                  'titles': ['explaining-parochialism-causal-account-political-polarization-changing-economic-environments',
#                             'intelligence-officials-warn-climate-change-is-worldwide-threat-insideclimate-news',
#                             'alerts-for-city-toronto-environment-canada']},
#  'ethics': {'count': 11,
#             'sim_words': ['ethics',
#                           'ethical',
#                           'ethical',
#                           'ethical',
#                           'ethical',
#                           'ethical',
#                           'ethics',
#                           'ethical',
#                           'ethical',
#                           'ethical',
#                           'ethics'],
#             'titles': ['pop-culture-ai-and-ethics',
#                        'google-created-responsible-innovation-team-check-ai-ethical-quartz',
#                        'invest-ai-ethical-future-techcrunch',
#                        'london-helsinki-collaborate-ethical-ai-data-smart-cities-world',
#                        'google-completed-ethical-reviews-ai-projects-products-deals-venturebeat',
#                        'council-post-the-top-three-considerations-for-designing-ethical-ai',
#                        'highlights-transcript-zuckerberg-word-ethics-talk-techcrunch',
#                        'the-folly-trolleys-ethical-challenges-autonomous-vehicles',
#                        'the-folly-trolleys-ethical-challenges-autonomous-vehicles',
#                        'invest-ai-ethical-future-techcrunch',
#                        'ai-ethics-artificial-intelligence-robots-society']},
#  'experience': {'count': 3,
#                 'sim_words': ['experience', 'experience', 'experiences'],
#                 'titles': ['samsung-teases-luxury-experience-buying-galaxy-fold-business-insider',
#                            'managing-cloud-migration-end-user-experience',
#                            'council-post-how-to-foster-positive-employee-experiences-to-drive-long-term-digital-transformations']},
#  'expertise': {'count': 1,
#                'sim_words': ['expertise'],
#                'titles': ['china-uses-dna-track-its-people-with-help-american-expertise-the-new-york-times']},
#  'faith': {'count': 1,
#            'sim_words': ['religion'],
#            'titles': ['virtual-afterlives-grieving-dead-twenty-first-century-assistant-professor-religion-candi-cann-candi-cann-google-books']},
#  'family': {'count': 1,
#             'sim_words': ['family'],
#             'titles': ['paid-family-leave-investment-public-health-handout']},
#  'fitness': {'count': 1,
#              'sim_words': ['fitness'],
#              'titles': ['health-fitness-startups-boom-business-insider']},
#  'focus': {'count': 1,
#            'sim_words': ['focus'],
#            'titles': ['why-conversational-programming-should-be-your-next-focus-area']},
#  'freedom': {'count': 2,
#              'sim_words': ['rights', 'rights'],
#              'titles': ['lake-erie-bill-rights-passes-toledo-ohio-special-election-vox',
#                         'cities-digital-rights']},
#  'fun': {'count': 5,
#          'sim_words': ['kids', 'kids', 'kids', 'kids', 'really'],
#          'titles': ['opinion-the-two-codes-your-kids-need-know-the-new-york-times',
#                     'when-kids-google-themselves-the-atlantic',
#                     'when-kids-google-themselves-the-atlantic',
#                     'mom-videos-youtube-kids-gave-children-instructions-suicide-cnn',
#                     'what-does-augmented-workforce-really-look-like']},
#  'giving': {'count': 5,
#             'sim_words': ['give', 'getting', 'gave', 'instead', 'give'],
#             'titles': ['you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj',
#                        'apple-dongle-problem-isn-getting-better-business-insider',
#                        'mom-videos-youtube-kids-gave-children-instructions-suicide-cnn',
#                        'worried-about-bias-ai-worry-about-humans-instead-center-data-innovation',
#                        'you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj']},
#  'growth': {'count': 5,
#             'sim_words': ['economic',
#                           'economic',
#                           'economic',
#                           'economic',
#                           'rise'],
#             'titles': ['data-new-oil-adam-schlosser-world-economic-forum-business-insider',
#                        'this-happen-natural-world-insects-disappeared-world-economic-forum',
#                        'explaining-parochialism-causal-account-political-polarization-changing-economic-environments',
#                        'the-new-geopolitics-artificial-intelligence-world-economic-forum',
#                        'chart-steady-rise-women-stem-gender-gap-remains-statista']},
#  'health': {'count': 3,
#             'sim_words': ['health', 'medical', 'health'],
#             'titles': ['paid-family-leave-investment-public-health-handout',
#                        'medical-it-must-boost-its-immune-system-compare-cloud',
#                        'health-fitness-startups-boom-business-insider']},
#  'honor': {'count': 1,
#            'sim_words': ['honor'],
#            'titles': ['microsoft-once-hated-clippy-cartoon-badge-honor-business-insider']},
#  'imagination': {'count': 1,
#                  'sim_words': ['creativity'],
#                  'titles': ['automating-creativity-why-short-talk-samim-youtube']},
#  'impact': {'count': 1,
#             'sim_words': ['impact'],
#             'titles': ['how-influencers-impact-media-agenda-ai-onalytica']},
#  'individuality': {'count': 1,
#                    'sim_words': ['creativity'],
#                    'titles': ['automating-creativity-why-short-talk-samim-youtube']},
#  'industry': {'count': 63,
#               'sim_words': ['business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'industry',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'companies',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business',
#                             'business'],
#               'titles': ['samsung-announces-new-galaxy-plus-phones-business-insider',
#                          'facebook-cryptocurrency-whatsapp-launch-half-report-business-insider',
#                          'israeli-moon-mission-spaceil-successfully-launches-spacex-rocket-business-insider',
#                          'tesla-closing-stores-means-layoffs-retail-employees-business-insider',
#                          'interesting-practical-amazon-purchases-business-insider',
#                          'fitbit-sees-current-quarter-revenue-estimates-business-insider',
#                          'google-announced-end-forced-arbitration-internal-matters-business-insider',
#                          'purchases-wish-told-apartment-business-insider',
#                          'apple-release-new-ipod-business-insider',
#                          'travel-essentials-reduce-stress-away-suitcase-clear-membership-business-insider',
#                          'data-new-oil-adam-schlosser-world-economic-forum-business-insider',
#                          'billion-video-conferencing-company-zoom-aiming-april-ipo-business-insider',
#                          'hbo-ceo-richard-plepler-leaving-nearly-years-business-insider',
#                          'how-to-leverage-artificial-intelligence-to-gain-business-advantage',
#                          'revealed-gambling-industry-targets-poor-people-ex-gamblers-society-the-guardian',
#                          'open-letter-elon-musk-twitter-use-business-insider',
#                          'watch-samsung-unveil-foldable-phone-galaxy-fold-business-insider',
#                          'where-famous-tech-ceos-went-college-studied-list-business-insider',
#                          'samsung-galaxy-specs-price-release-date-business-insider',
#                          'samsung-galaxy-fold-massive-risk-buys-business-insider',
#                          'health-fitness-startups-boom-business-insider',
#                          'what-genetically-engineered-crispr-baby-business-insider',
#                          'hound-labs-startup-founded-doctor-invents-marijuana-breathalyzer-business-insider',
#                          'everything-know-nintendo-switch-business-insider',
#                          'samsung-releases-video-galaxy-fold-business-insider',
#                          'google-cloud-acquiring-alooma-help-migrate-data-cloud-business-insider',
#                          'google-says-nest-microphone-never-supposed-secret-business-insider',
#                          'samsung-teases-luxury-experience-buying-galaxy-fold-business-insider',
#                          'samsung-galaxy-fold-release-date-price-specs-features-business-insider',
#                          'quilty-weighted-blanket-review-it-helped-fall-asleep-minutes-business-insider',
#                          'review-nokia-pureview-camera-smartphone-business-insider',
#                          'reasons-wireless-chargers-don-work-business-insider',
#                          'floating-home-withstand-category-hurricanes-photos-business-insider',
#                          'new-apple-watch-include-sleep-tracking-feature-report-business-insider',
#                          'hsbc-erwan-rambourg-forecasts-trouble-ahead-apple-china-business-insider',
#                          'apple-dongle-problem-isn-getting-better-business-insider',
#                          'tesla-suspends-orders-ahead-elon-musk-big-announcement-business-insider',
#                          'retail-startups-shop-amazon-casper-leesa-mvmt-business-insider',
#                          'cyber-security-threats-companies-face-digital-age',
#                          'samsung-reveals-new-cheaper-galaxy-phone-business-insider',
#                          'bill-gates-trampoline-room-million-medina-mansion-business-insider',
#                          'apple-details-layoffs-self-driving-car-unit-filing-business-insider',
#                          'huawei-mate-specifications-release-date-photos-price-business-insider',
#                          'walmart-new-private-label-tech-accessories-line-motile-affordable-stylish-business-insider',
#                          'lockly-secure-plus-smart-lock-review-fingerprint-reader-boosts-home-security-business-insider',
#                          'tesla-closing-stores-adopting-online-only-model-business-insider',
#                          'inventions-save-earth-business-insider',
#                          'microsoft-vmware-partnership-won-amazon-happy-business-insider',
#                          'watch-samsung-foldable-phone-galaxy-event-minutes-business-insider',
#                          'peter-thiel-founders-fund-delivering-huge-returns-investors-business-insider',
#                          'maxwell-investors-sue-block-tesla-acquisition-business-insider',
#                          'executives-caught-florida-massage-parlor-prostitution-sting-business-insider',
#                          'lyft-uber-let-drivers-stock-ipo-price-business-insider',
#                          'buffett-apple-stock-price-if-cheaper-we-buying-it-business-insider',
#                          'co-founder-ev-williams-leaving-twitter-board-business-insider',
#                          'massdrop-vast-curved-gaming-monitor-review-perfect-option-business-insider',
#                          'amtrak-train-stuck-hours-snow-hitting-tree-business-insider',
#                          'photos-grand-canyon-history-year-anniversary-business-insider',
#                          'wedbush-dan-ives-apple-acquire-hollywood-studio-lose-streaming-business-insider',
#                          'microsoft-once-hated-clippy-cartoon-badge-honor-business-insider',
#                          'researchers-lab-grown-thc-cbd-startups-blossoming-business-insider',
#                          'watch-samsung-unveil-galaxy-business-insider',
#                          'apple-can-compete-samsung-galaxy-fold-goldman-sachs-says-business-insider']},
#  'ingenuity': {'count': 1,
#                'sim_words': ['creativity'],
#                'titles': ['automating-creativity-why-short-talk-samim-youtube']},
#  'initiative': {'count': 1,
#                 'sim_words': ['initiative'],
#                 'titles': ['ai-weekly-trump-american-ai-initiative-lacks-substance-venturebeat']},
#  'innovation': {'count': 3,
#                 'sim_words': ['creativity', 'innovation', 'innovation'],
#                 'titles': ['automating-creativity-why-short-talk-samim-youtube',
#                            'google-created-responsible-innovation-team-check-ai-ethical-quartz',
#                            'worried-about-bias-ai-worry-about-humans-instead-center-data-innovation']},
#  'intelligence': {'count': 8,
#                   'sim_words': ['intelligence',
#                                 'intelligence',
#                                 'intelligence',
#                                 'intelligence',
#                                 'intelligence',
#                                 'intelligence',
#                                 'intelligence',
#                                 'intelligence'],
#                   'titles': ['artificial-intelligence-describing-smells-ibm-research-quartz',
#                              'how-to-leverage-artificial-intelligence-to-gain-business-advantage',
#                              'artificial-intelligence-salaries-heading-skyward-machine-learning-memoirs-medium',
#                              'china-military-rushing-use-artificial-intelligence-mit-technology-review',
#                              'intelligence-officials-warn-climate-change-is-worldwide-threat-insideclimate-news',
#                              'the-new-geopolitics-artificial-intelligence-world-economic-forum',
#                              'maximizing-data-intelligence-compliant-automated-policy-enforcement',
#                              'ai-ethics-artificial-intelligence-robots-society']},
#  'investing': {'count': 3,
#                'sim_words': ['investment', 'invest', 'invest'],
#                'titles': ['paid-family-leave-investment-public-health-handout',
#                           'invest-ai-ethical-future-techcrunch',
#                           'invest-ai-ethical-future-techcrunch']},
#  'involvement': {'count': 1,
#                  'sim_words': ['alleged'],
#                  'titles': ['hhs-docs-thousands-alleged-incidents-sexual-abuse-unaccompanied-minors-custody-cnnpolitics']},
#  'justice': {'count': 1,
#              'sim_words': ['justice'],
#              'titles': ['justice-clarence-thomas-calls-reconsideration-landmark-libel-ruling-the-new-york-times']},
#  'knowledge': {'count': 4,
#                'sim_words': ['information',
#                              'information',
#                              'expertise',
#                              'information'],
#                'titles': ['you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj',
#                           'data-error-exposes-patient-information-newsroom',
#                           'china-uses-dna-track-its-people-with-help-american-expertise-the-new-york-times',
#                           'you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj']},
#  'leadership': {'count': 4,
#                 'sim_words': ['leaders', 'leadership', 'leaders', 'leaders'],
#                 'titles': ['why-do-so-many-incompetent-men-become-leaders',
#                            'usc-graduate-nannearl-lekesia-brown-combines-tech-nonprofit-leadership-blacks-in-technology',
#                            'bath-trains-new-generation-leaders-accountable-responsible-transparent-ai',
#                            'millennial-ai-leaders-follow']},
#  'learning': {'count': 9,
#               'sim_words': ['learning',
#                             'learning',
#                             'learning',
#                             'learning',
#                             'learn',
#                             'learning',
#                             'learn',
#                             'learning',
#                             'learning'],
#               'titles': ['machine-learning-contributing-reproducibility-crisis-science-mit-technology-review',
#                          'artificial-intelligence-salaries-heading-skyward-machine-learning-memoirs-medium',
#                          'human-pose-machines-self-supervised-learning',
#                          'ai-driven-learning-essential-digital-transformation',
#                          'pricing-algorithms-learn-collude-raise-prices-mit-technology-review',
#                          'the-five-levels-machine-learning-use-cases-allie-miller-medium',
#                          'what-cloud-computing-learn-good-bbq-infoworld',
#                          'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet',
#                          'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet']},
#  'love': {'count': 1,
#           'sim_words': ['love'],
#           'titles': ['ruyi-royal-love-in-the-palace-official-trailer-eng-sub-janine-chang-wallace-huo-zhou-xun-youtube']},
#  'meaning': {'count': 3,
#              'sim_words': ['means', 'word', 'word'],
#              'titles': ['tesla-closing-stores-means-layoffs-retail-employees-business-insider',
#                         'contextual-word-representations-contextual-introduction',
#                         'highlights-transcript-zuckerberg-word-ethics-talk-techcrunch']},
#  'money': {'count': 3,
#            'sim_words': ['paid', 'donations', 'fund'],
#            'titles': ['paid-family-leave-investment-public-health-handout',
#                       'chart-harvard-received-billion-in-donations-last-year-statista',
#                       'peter-thiel-founders-fund-delivering-huge-returns-investors-business-insider']},
#  'order': {'count': 2,
#            'sim_words': ['orders', 'order'],
#            'titles': ['tesla-suspends-orders-ahead-elon-musk-big-announcement-business-insider',
#                       'how-brain-keeps-its-memories-right-order-wired']},
#  'organization': {'count': 1,
#                   'sim_words': ['nonprofit'],
#                   'titles': ['usc-graduate-nannearl-lekesia-brown-combines-tech-nonprofit-leadership-blacks-in-technology']},
#  'originality': {'count': 1,
#                  'sim_words': ['creativity'],
#                  'titles': ['automating-creativity-why-short-talk-samim-youtube']},
#  'partnership': {'count': 2,
#                  'sim_words': ['partnership', 'partnership'],
#                  'titles': ['prepared-for-partnership-trust-distrust-international-cooperation',
#                             'microsoft-vmware-partnership-won-amazon-happy-business-insider']},
#  'passion': {'count': 1,
#              'sim_words': ['love'],
#              'titles': ['ruyi-royal-love-in-the-palace-official-trailer-eng-sub-janine-chang-wallace-huo-zhou-xun-youtube']},
#  'power': {'count': 1,
#            'sim_words': ['power'],
#            'titles': ['computational-power-automated-use-whatsapp-elections']},
#  'privacy': {'count': 3,
#              'sim_words': ['privacy', 'privacy', 'privacy'],
#              'titles': ['silicon-valley-oversight-democrats-probe-tech-privacy-practices-the-washington-post',
#                         'even-iab-warned-adtech-risks-eu-privacy-rules-techcrunch',
#                         'discovery-cameras-built-airlines-seats-sparks-privacy-concerns-the-verge']},
#  'reason': {'count': 38,
#             'sim_words': ['actually',
#                           'why',
#                           'need',
#                           'know',
#                           'why',
#                           'what',
#                           'what',
#                           'not',
#                           'should',
#                           'explain',
#                           'what',
#                           'know',
#                           'why',
#                           'why',
#                           'do',
#                           'reasons',
#                           'come',
#                           'want',
#                           'why',
#                           'should',
#                           'why',
#                           'think',
#                           'know',
#                           'what',
#                           'does',
#                           'really',
#                           'even',
#                           'think',
#                           'what',
#                           'do',
#                           'if',
#                           'if',
#                           'what',
#                           'worry',
#                           'that',
#                           'actually',
#                           'because',
#                           'that'],
#             'titles': ['facebook-clear-history-tool-actually-happen-it-time',
#                        'why-mass-data-fragmentation-matters-compare-cloud',
#                        'opinion-the-two-codes-your-kids-need-know-the-new-york-times',
#                        'opinion-the-two-codes-your-kids-need-know-the-new-york-times',
#                        'automating-creativity-why-short-talk-samim-youtube',
#                        'what-happens-younger-workers-when-older-workers-don-retire',
#                        'what-is-public-the-message-medium',
#                        'mondaq-not-allowed-bad-crawler',
#                        'should-robots-marketed-children-teenagers',
#                        'could-counterfactuals-explain-algorithmic-decisions-without-opening-black-box-oxford-internet-institute',
#                        'what-genetically-engineered-crispr-baby-business-insider',
#                        'everything-know-nintendo-switch-business-insider',
#                        'why-scientists-silent-gene-edited-babies',
#                        'why-do-so-many-incompetent-men-become-leaders',
#                        'why-do-so-many-incompetent-men-become-leaders',
#                        'reasons-wireless-chargers-don-work-business-insider',
#                        'come-on-the-hives-youtube',
#                        'how-lost-legs-gained-want-inspiring-the-outline',
#                        'why-conversational-programming-should-be-your-next-focus-area',
#                        'why-conversational-programming-should-be-your-next-focus-area',
#                        'why-mass-data-fragmentation-matters-compare-cloud',
#                        'wealth-inequality-is-way-worse-than-you-think-and-tax-havens-play-big-role',
#                        'containers-the-pros-cons-know-infoworld',
#                        'what-does-augmented-workforce-really-look-like',
#                        'what-does-augmented-workforce-really-look-like',
#                        'what-does-augmented-workforce-really-look-like',
#                        'even-iab-warned-adtech-risks-eu-privacy-rules-techcrunch',
#                        'at-think-ibm-brings-ai-multicloud-confronts-formidable-challenges-siliconangle',
#                        'what-to-do-if-you-ve-been-hacked-compare-cloud',
#                        'what-to-do-if-you-ve-been-hacked-compare-cloud',
#                        'what-to-do-if-you-ve-been-hacked-compare-cloud',
#                        'buffett-apple-stock-price-if-cheaper-we-buying-it-business-insider',
#                        'what-cloud-computing-learn-good-bbq-infoworld',
#                        'worried-about-bias-ai-worry-about-humans-instead-center-data-innovation',
#                        'new-job-insight-that-could-unlock-higher-salary-official-linkedin-blog',
#                        'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet',
#                        'nike-android-app-is-bricking-shoes-because-that-headline-we-write-extremetech',
#                        'nike-android-app-is-bricking-shoes-because-that-headline-we-write-extremetech']},
#  'recognition': {'count': 2,
#                  'sim_words': ['recognition', 'recognize'],
#                  'titles': ['chinese-company-leaves-muslim-tracking-facial-recognition-database-exposed-online-zdnet',
#                             'the-cybersecurity-your-phone-soon-recognize-based-walk-the-washington-post']},
#  'relief': {'count': 3,
#             'sim_words': ['humanitarian', 'humanitarian', 'aid'],
#             'titles': ['data-fellows-programme-the-centre-humanitarian-data',
#                        'welcome-humanitarian-data-exchange',
#                        'aid-to-venezuela-just-lit-stick-of-dynamite-painted-to-look-like-carrot']},
#  'responsibility': {'count': 2,
#                     'sim_words': ['responsible', 'responsible'],
#                     'titles': ['google-created-responsible-innovation-team-check-ai-ethical-quartz',
#                                'bath-trains-new-generation-leaders-accountable-responsible-transparent-ai']},
#  'rest': {'count': 4,
#           'sim_words': ['all', 'all', 'stay', 'just'],
#           'titles': ['audi-cars-tell-you-how-fast-go-catch-all-green-lights-wired',
#                      'one-ring-rule-all-darkness-bind',
#                      'for-novartis-michael-cohen-affair-won-stay-dead-stat',
#                      'aid-to-venezuela-just-lit-stick-of-dynamite-painted-to-look-like-carrot']},
#  'safety': {'count': 1,
#             'sim_words': ['safety'],
#             'titles': ['linux-foundation-launches-elisa-open-source-project-building-safety-critical-systems-venturebeat']},
#  'science': {'count': 14,
#              'sim_words': ['research',
#                            'science',
#                            'technology',
#                            'science',
#                            'technology',
#                            'technology',
#                            'science',
#                            'research',
#                            'technology',
#                            'science',
#                            'technology',
#                            'technology',
#                            'scientific',
#                            'science'],
#              'titles': ['artificial-intelligence-describing-smells-ibm-research-quartz',
#                         'machine-learning-contributing-reproducibility-crisis-science-mit-technology-review',
#                         'machine-learning-contributing-reproducibility-crisis-science-mit-technology-review',
#                         'introducing-world-data-management-platform-data-science-immuta',
#                         'cloud-based-ai-technology-propels-cardiovascular-medicine-forward',
#                         'china-military-rushing-use-artificial-intelligence-mit-technology-review',
#                         'infosurhoy-latest-science-news-reports',
#                         'this-algorithm-decodes-rat-squeaks-revolutionize-animal-research-youtube',
#                         'usc-graduate-nannearl-lekesia-brown-combines-tech-nonprofit-leadership-blacks-in-technology',
#                         'deliberate-data-science-medium',
#                         'pricing-algorithms-learn-collude-raise-prices-mit-technology-review',
#                         'anti-vaxx-propaganda-gone-viral-facebook-pinterest-cure-technology-the-guardian',
#                         'towards-reconstructing-intelligible-speech-human-auditory-cortex-scientific-reports',
#                         'we-re-women-science-we-re-scientists']},
#  'security': {'count': 3,
#               'sim_words': ['security', 'security', 'security'],
#               'titles': ['is-drive-by-sex-toy-hacking-wake-up-britain-internet-security-chi-onwurah-opinion-the-guardian',
#                          'cyber-security-threats-companies-face-digital-age',
#                          'lockly-secure-plus-smart-lock-review-fingerprint-reader-boosts-home-security-business-insider']},
#  'service': {'count': 3,
#              'sim_words': ['service', 'service', 'service'],
#              'titles': ['citymapper-announces-subscription-service-multiple-transportation-methods-techcrunch',
#                         'google-expected-reveal-game-streaming-service-gdc-march-extremetech',
#                         'service-unavailable']},
#  'sexuality': {'count': 2,
#                'sim_words': ['sexual', 'sexual'],
#                'titles': ['naduac-sexual-assaults-date-incident-fy',
#                           'hhs-docs-thousands-alleged-incidents-sexual-abuse-unaccompanied-minors-custody-cnnpolitics']},
#  'speed': {'count': 1,
#            'sim_words': ['speed'],
#            'titles': ['china-unveils-new-generation-high-speed-train-youtube']},
#  'structure': {'count': 1,
#                'sim_words': ['building'],
#                'titles': ['linux-foundation-launches-elisa-open-source-project-building-safety-critical-systems-venturebeat']},
#  'success': {'count': 2,
#              'sim_words': ['successful', 'success'],
#              'titles': ['america-professional-elite-wealthy-successful-miserable-the-new-york-times',
#                         'tips-guaranteed-improve-your-startup-success']},
#  'surprise': {'count': 1,
#               'sim_words': ['surprise'],
#               'titles': ['surprise-ai-in']},
#  'teaching': {'count': 8,
#               'sim_words': ['learning',
#                             'learning',
#                             'learning',
#                             'learning',
#                             'graduate',
#                             'learning',
#                             'learning',
#                             'learning'],
#               'titles': ['machine-learning-contributing-reproducibility-crisis-science-mit-technology-review',
#                          'artificial-intelligence-salaries-heading-skyward-machine-learning-memoirs-medium',
#                          'human-pose-machines-self-supervised-learning',
#                          'ai-driven-learning-essential-digital-transformation',
#                          'usc-graduate-nannearl-lekesia-brown-combines-tech-nonprofit-leadership-blacks-in-technology',
#                          'the-five-levels-machine-learning-use-cases-allie-miller-medium',
#                          'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet',
#                          'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet']},
#  'trust': {'count': 1,
#            'sim_words': ['trust'],
#            'titles': ['prepared-for-partnership-trust-distrust-international-cooperation']},
#  'truth': {'count': 1,
#            'sim_words': ['truth'],
#            'titles': ['the-deadly-truth-world-built-men-stab-vests-car-crashes-life-style-the-guardian']},
#  'victory': {'count': 3,
#              'sim_words': ['won', 'won', 'won'],
#              'titles': ['ai-won-relieve-misery-facebook-human-moderators-the-verge',
#                         'for-novartis-michael-cohen-affair-won-stay-dead-stat',
#                         'microsoft-vmware-partnership-won-amazon-happy-business-insider']},
#  'wealth': {'count': 2,
#             'sim_words': ['wealth', 'wealth'],
#             'titles': ['color-wealth-miami-tickets-mon-feb-am-eventbrite',
#                        'wealth-inequality-is-way-worse-than-you-think-and-tax-havens-play-big-role']},
#  'winning': {'count': 4,
#              'sim_words': ['won', 'won', 'won', 'losing'],
#              'titles': ['ai-won-relieve-misery-facebook-human-moderators-the-verge',
#                         'for-novartis-michael-cohen-affair-won-stay-dead-stat',
#                         'microsoft-vmware-partnership-won-amazon-happy-business-insider',
#                         'florida-inmate-sues-losing-access-purchased-digital-music-files']},
#  'wonder': {'count': 6,
#             'sim_words': ['why', 'why', 'why', 'why', 'why', 'why'],
#             'titles': ['why-mass-data-fragmentation-matters-compare-cloud',
#                        'automating-creativity-why-short-talk-samim-youtube',
#                        'why-scientists-silent-gene-edited-babies',
#                        'why-do-so-many-incompetent-men-become-leaders',
#                        'why-conversational-programming-should-be-your-next-focus-area',
#                        'why-mass-data-fragmentation-matters-compare-cloud']}}

# %%
value_mention_arr = []
for value, ent in value_mentions.items():
    value_mention_arr.append([ent["count"], value, ent["sim_words"], value, ent["titles"]])
    
# sort by count
pprint(sorted(value_mention_arr))
# Out:
# [[1,
#   'accomplishment',
#   ['remarkable'],
#   'accomplishment',
#   ['for-black-history-month-remarkable-women-men-we-overlooked-since-the-new-york-times']],
#  [1,
#   'accountability',
#   ['oversight'],
#   'accountability',
#   ['silicon-valley-oversight-democrats-probe-tech-privacy-practices-the-washington-post']],
#  [1,
#   'art',
#   ['artist'],
#   'art',
#   ['ted-nelson-artist-philosopher-filmmaker-new-media-pioneer-youtube']],
#  [1,
#   'commitment',
#   ['promise'],
#   'commitment',
#   ['the-soothing-promise-our-own-artisanal-internet-wired']],
#  [1,
#   'completion',
#   ['completed'],
#   'completion',
#   ['google-completed-ethical-reviews-ai-projects-products-deals-venturebeat']],
#  [1,
#   'coordination',
#   ['cooperation'],
#   'coordination',
#   ['prepared-for-partnership-trust-distrust-international-cooperation']],
#  [1,
#   'country',
#   ['countries'],
#   'country',
#   ['how-green-new-deal-exploit-developing-countries']],
#  [1,
#   'desire',
#   ['wish'],
#   'desire',
#   ['purchases-wish-told-apartment-business-insider']],
#  [1,
#   'discovery',
#   ['discovery'],
#   'discovery',
#   ['discovery-cameras-built-airlines-seats-sparks-privacy-concerns-the-verge']],
#  [1,
#   'expertise',
#   ['expertise'],
#   'expertise',
#   ['china-uses-dna-track-its-people-with-help-american-expertise-the-new-york-times']],
#  [1,
#   'faith',
#   ['religion'],
#   'faith',
#   ['virtual-afterlives-grieving-dead-twenty-first-century-assistant-professor-religion-candi-cann-candi-cann-google-books']],
#  [1,
#   'family',
#   ['family'],
#   'family',
#   ['paid-family-leave-investment-public-health-handout']],
#  [1,
#   'fitness',
#   ['fitness'],
#   'fitness',
#   ['health-fitness-startups-boom-business-insider']],
#  [1,
#   'focus',
#   ['focus'],
#   'focus',
#   ['why-conversational-programming-should-be-your-next-focus-area']],
#  [1,
#   'honor',
#   ['honor'],
#   'honor',
#   ['microsoft-once-hated-clippy-cartoon-badge-honor-business-insider']],
#  [1,
#   'imagination',
#   ['creativity'],
#   'imagination',
#   ['automating-creativity-why-short-talk-samim-youtube']],
#  [1,
#   'impact',
#   ['impact'],
#   'impact',
#   ['how-influencers-impact-media-agenda-ai-onalytica']],
#  [1,
#   'individuality',
#   ['creativity'],
#   'individuality',
#   ['automating-creativity-why-short-talk-samim-youtube']],
#  [1,
#   'ingenuity',
#   ['creativity'],
#   'ingenuity',
#   ['automating-creativity-why-short-talk-samim-youtube']],
#  [1,
#   'initiative',
#   ['initiative'],
#   'initiative',
#   ['ai-weekly-trump-american-ai-initiative-lacks-substance-venturebeat']],
#  [1,
#   'involvement',
#   ['alleged'],
#   'involvement',
#   ['hhs-docs-thousands-alleged-incidents-sexual-abuse-unaccompanied-minors-custody-cnnpolitics']],
#  [1,
#   'justice',
#   ['justice'],
#   'justice',
#   ['justice-clarence-thomas-calls-reconsideration-landmark-libel-ruling-the-new-york-times']],
#  [1,
#   'love',
#   ['love'],
#   'love',
#   ['ruyi-royal-love-in-the-palace-official-trailer-eng-sub-janine-chang-wallace-huo-zhou-xun-youtube']],
#  [1,
#   'organization',
#   ['nonprofit'],
#   'organization',
#   ['usc-graduate-nannearl-lekesia-brown-combines-tech-nonprofit-leadership-blacks-in-technology']],
#  [1,
#   'originality',
#   ['creativity'],
#   'originality',
#   ['automating-creativity-why-short-talk-samim-youtube']],
#  [1,
#   'passion',
#   ['love'],
#   'passion',
#   ['ruyi-royal-love-in-the-palace-official-trailer-eng-sub-janine-chang-wallace-huo-zhou-xun-youtube']],
#  [1,
#   'power',
#   ['power'],
#   'power',
#   ['computational-power-automated-use-whatsapp-elections']],
#  [1,
#   'safety',
#   ['safety'],
#   'safety',
#   ['linux-foundation-launches-elisa-open-source-project-building-safety-critical-systems-venturebeat']],
#  [1,
#   'speed',
#   ['speed'],
#   'speed',
#   ['china-unveils-new-generation-high-speed-train-youtube']],
#  [1,
#   'structure',
#   ['building'],
#   'structure',
#   ['linux-foundation-launches-elisa-open-source-project-building-safety-critical-systems-venturebeat']],
#  [1, 'surprise', ['surprise'], 'surprise', ['surprise-ai-in']],
#  [1,
#   'trust',
#   ['trust'],
#   'trust',
#   ['prepared-for-partnership-trust-distrust-international-cooperation']],
#  [1,
#   'truth',
#   ['truth'],
#   'truth',
#   ['the-deadly-truth-world-built-men-stab-vests-car-crashes-life-style-the-guardian']],
#  [2,
#   'competition',
#   ['competitive', 'compete'],
#   'competition',
#   ['blockchain-adopting-legal-frameworks-gain-competitive-advantage',
#    'apple-can-compete-samsung-galaxy-fold-goldman-sachs-says-business-insider']],
#  [2,
#   'control',
#   ['control', 'controlled'],
#   'control',
#   ['darpa-thinks-ai-could-help-troops-telepathically-control-machines-defense-one',
#    'stanford-researchers-develop-brain-controlled-typing-people-paralysis-youtube']],
#  [2,
#   'cooperation',
#   ['cooperation', 'countries'],
#   'cooperation',
#   ['prepared-for-partnership-trust-distrust-international-cooperation',
#    'how-green-new-deal-exploit-developing-countries']],
#  [2,
#   'drive',
#   ['drive', 'drive'],
#   'drive',
#   ['is-drive-by-sex-toy-hacking-wake-up-britain-internet-security-chi-onwurah-opinion-the-guardian',
#    'council-post-how-to-foster-positive-employee-experiences-to-drive-long-term-digital-transformations']],
#  [2,
#   'education',
#   ['health', 'health'],
#   'education',
#   ['paid-family-leave-investment-public-health-handout',
#    'health-fitness-startups-boom-business-insider']],
#  [2,
#   'freedom',
#   ['rights', 'rights'],
#   'freedom',
#   ['lake-erie-bill-rights-passes-toledo-ohio-special-election-vox',
#    'cities-digital-rights']],
#  [2,
#   'order',
#   ['orders', 'order'],
#   'order',
#   ['tesla-suspends-orders-ahead-elon-musk-big-announcement-business-insider',
#    'how-brain-keeps-its-memories-right-order-wired']],
#  [2,
#   'partnership',
#   ['partnership', 'partnership'],
#   'partnership',
#   ['prepared-for-partnership-trust-distrust-international-cooperation',
#    'microsoft-vmware-partnership-won-amazon-happy-business-insider']],
#  [2,
#   'recognition',
#   ['recognition', 'recognize'],
#   'recognition',
#   ['chinese-company-leaves-muslim-tracking-facial-recognition-database-exposed-online-zdnet',
#    'the-cybersecurity-your-phone-soon-recognize-based-walk-the-washington-post']],
#  [2,
#   'responsibility',
#   ['responsible', 'responsible'],
#   'responsibility',
#   ['google-created-responsible-innovation-team-check-ai-ethical-quartz',
#    'bath-trains-new-generation-leaders-accountable-responsible-transparent-ai']],
#  [2,
#   'sexuality',
#   ['sexual', 'sexual'],
#   'sexuality',
#   ['naduac-sexual-assaults-date-incident-fy',
#    'hhs-docs-thousands-alleged-incidents-sexual-abuse-unaccompanied-minors-custody-cnnpolitics']],
#  [2,
#   'success',
#   ['successful', 'success'],
#   'success',
#   ['america-professional-elite-wealthy-successful-miserable-the-new-york-times',
#    'tips-guaranteed-improve-your-startup-success']],
#  [2,
#   'wealth',
#   ['wealth', 'wealth'],
#   'wealth',
#   ['color-wealth-miami-tickets-mon-feb-am-eventbrite',
#    'wealth-inequality-is-way-worse-than-you-think-and-tax-havens-play-big-role']],
#  [3,
#   'care',
#   ['health', 'medical', 'health'],
#   'care',
#   ['paid-family-leave-investment-public-health-handout',
#    'medical-it-must-boost-its-immune-system-compare-cloud',
#    'health-fitness-startups-boom-business-insider']],
#  [3,
#   'change',
#   ['need', 'changing', 'change'],
#   'change',
#   ['opinion-the-two-codes-your-kids-need-know-the-new-york-times',
#    'explaining-parochialism-causal-account-political-polarization-changing-economic-environments',
#    'intelligence-officials-warn-climate-change-is-worldwide-threat-insideclimate-news']],
#  [3,
#   'environment',
#   ['environments', 'climate', 'environment'],
#   'environment',
#   ['explaining-parochialism-causal-account-political-polarization-changing-economic-environments',
#    'intelligence-officials-warn-climate-change-is-worldwide-threat-insideclimate-news',
#    'alerts-for-city-toronto-environment-canada']],
#  [3,
#   'experience',
#   ['experience', 'experience', 'experiences'],
#   'experience',
#   ['samsung-teases-luxury-experience-buying-galaxy-fold-business-insider',
#    'managing-cloud-migration-end-user-experience',
#    'council-post-how-to-foster-positive-employee-experiences-to-drive-long-term-digital-transformations']],
#  [3,
#   'health',
#   ['health', 'medical', 'health'],
#   'health',
#   ['paid-family-leave-investment-public-health-handout',
#    'medical-it-must-boost-its-immune-system-compare-cloud',
#    'health-fitness-startups-boom-business-insider']],
#  [3,
#   'innovation',
#   ['creativity', 'innovation', 'innovation'],
#   'innovation',
#   ['automating-creativity-why-short-talk-samim-youtube',
#    'google-created-responsible-innovation-team-check-ai-ethical-quartz',
#    'worried-about-bias-ai-worry-about-humans-instead-center-data-innovation']],
#  [3,
#   'investing',
#   ['investment', 'invest', 'invest'],
#   'investing',
#   ['paid-family-leave-investment-public-health-handout',
#    'invest-ai-ethical-future-techcrunch',
#    'invest-ai-ethical-future-techcrunch']],
#  [3,
#   'meaning',
#   ['means', 'word', 'word'],
#   'meaning',
#   ['tesla-closing-stores-means-layoffs-retail-employees-business-insider',
#    'contextual-word-representations-contextual-introduction',
#    'highlights-transcript-zuckerberg-word-ethics-talk-techcrunch']],
#  [3,
#   'money',
#   ['paid', 'donations', 'fund'],
#   'money',
#   ['paid-family-leave-investment-public-health-handout',
#    'chart-harvard-received-billion-in-donations-last-year-statista',
#    'peter-thiel-founders-fund-delivering-huge-returns-investors-business-insider']],
#  [3,
#   'privacy',
#   ['privacy', 'privacy', 'privacy'],
#   'privacy',
#   ['silicon-valley-oversight-democrats-probe-tech-privacy-practices-the-washington-post',
#    'even-iab-warned-adtech-risks-eu-privacy-rules-techcrunch',
#    'discovery-cameras-built-airlines-seats-sparks-privacy-concerns-the-verge']],
#  [3,
#   'relief',
#   ['humanitarian', 'humanitarian', 'aid'],
#   'relief',
#   ['data-fellows-programme-the-centre-humanitarian-data',
#    'welcome-humanitarian-data-exchange',
#    'aid-to-venezuela-just-lit-stick-of-dynamite-painted-to-look-like-carrot']],
#  [3,
#   'security',
#   ['security', 'security', 'security'],
#   'security',
#   ['is-drive-by-sex-toy-hacking-wake-up-britain-internet-security-chi-onwurah-opinion-the-guardian',
#    'cyber-security-threats-companies-face-digital-age',
#    'lockly-secure-plus-smart-lock-review-fingerprint-reader-boosts-home-security-business-insider']],
#  [3,
#   'service',
#   ['service', 'service', 'service'],
#   'service',
#   ['citymapper-announces-subscription-service-multiple-transportation-methods-techcrunch',
#    'google-expected-reveal-game-streaming-service-gdc-march-extremetech',
#    'service-unavailable']],
#  [3,
#   'victory',
#   ['won', 'won', 'won'],
#   'victory',
#   ['ai-won-relieve-misery-facebook-human-moderators-the-verge',
#    'for-novartis-michael-cohen-affair-won-stay-dead-stat',
#    'microsoft-vmware-partnership-won-amazon-happy-business-insider']],
#  [4,
#   'challenge',
#   ['challenges', 'challenges', 'challenges', 'challenge'],
#   'challenge',
#   ['at-think-ibm-brings-ai-multicloud-confronts-formidable-challenges-siliconangle',
#    'the-folly-trolleys-ethical-challenges-autonomous-vehicles',
#    'the-folly-trolleys-ethical-challenges-autonomous-vehicles',
#    'challenge-chart-js-starter-app-youtube']],
#  [4,
#   'creativity',
#   ['creativity', 'innovation', 'creative', 'innovation'],
#   'creativity',
#   ['automating-creativity-why-short-talk-samim-youtube',
#    'google-created-responsible-innovation-team-check-ai-ethical-quartz',
#    'creative-candidate-sourcing-strategies-ikea-spotify-deloitte-hire-google',
#    'worried-about-bias-ai-worry-about-humans-instead-center-data-innovation']],
#  [4,
#   'economy',
#   ['economic', 'economic', 'economic', 'economic'],
#   'economy',
#   ['data-new-oil-adam-schlosser-world-economic-forum-business-insider',
#    'this-happen-natural-world-insects-disappeared-world-economic-forum',
#    'explaining-parochialism-causal-account-political-polarization-changing-economic-environments',
#    'the-new-geopolitics-artificial-intelligence-world-economic-forum']],
#  [4,
#   'knowledge',
#   ['information', 'information', 'expertise', 'information'],
#   'knowledge',
#   ['you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj',
#    'data-error-exposes-patient-information-newsroom',
#    'china-uses-dna-track-its-people-with-help-american-expertise-the-new-york-times',
#    'you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj']],
#  [4,
#   'leadership',
#   ['leaders', 'leadership', 'leaders', 'leaders'],
#   'leadership',
#   ['why-do-so-many-incompetent-men-become-leaders',
#    'usc-graduate-nannearl-lekesia-brown-combines-tech-nonprofit-leadership-blacks-in-technology',
#    'bath-trains-new-generation-leaders-accountable-responsible-transparent-ai',
#    'millennial-ai-leaders-follow']],
#  [4,
#   'rest',
#   ['all', 'all', 'stay', 'just'],
#   'rest',
#   ['audi-cars-tell-you-how-fast-go-catch-all-green-lights-wired',
#    'one-ring-rule-all-darkness-bind',
#    'for-novartis-michael-cohen-affair-won-stay-dead-stat',
#    'aid-to-venezuela-just-lit-stick-of-dynamite-painted-to-look-like-carrot']],
#  [4,
#   'winning',
#   ['won', 'won', 'won', 'losing'],
#   'winning',
#   ['ai-won-relieve-misery-facebook-human-moderators-the-verge',
#    'for-novartis-michael-cohen-affair-won-stay-dead-stat',
#    'microsoft-vmware-partnership-won-amazon-happy-business-insider',
#    'florida-inmate-sues-losing-access-purchased-digital-music-files']],
#  [5,
#   'fun',
#   ['kids', 'kids', 'kids', 'kids', 'really'],
#   'fun',
#   ['opinion-the-two-codes-your-kids-need-know-the-new-york-times',
#    'when-kids-google-themselves-the-atlantic',
#    'when-kids-google-themselves-the-atlantic',
#    'mom-videos-youtube-kids-gave-children-instructions-suicide-cnn',
#    'what-does-augmented-workforce-really-look-like']],
#  [5,
#   'giving',
#   ['give', 'getting', 'gave', 'instead', 'give'],
#   'giving',
#   ['you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj',
#    'apple-dongle-problem-isn-getting-better-business-insider',
#    'mom-videos-youtube-kids-gave-children-instructions-suicide-cnn',
#    'worried-about-bias-ai-worry-about-humans-instead-center-data-innovation',
#    'you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj']],
#  [5,
#   'growth',
#   ['economic', 'economic', 'economic', 'economic', 'rise'],
#   'growth',
#   ['data-new-oil-adam-schlosser-world-economic-forum-business-insider',
#    'this-happen-natural-world-insects-disappeared-world-economic-forum',
#    'explaining-parochialism-causal-account-political-polarization-changing-economic-environments',
#    'the-new-geopolitics-artificial-intelligence-world-economic-forum',
#    'chart-steady-rise-women-stem-gender-gap-remains-statista']],
#  [6,
#   'wonder',
#   ['why', 'why', 'why', 'why', 'why', 'why'],
#   'wonder',
#   ['why-mass-data-fragmentation-matters-compare-cloud',
#    'automating-creativity-why-short-talk-samim-youtube',
#    'why-scientists-silent-gene-edited-babies',
#    'why-do-so-many-incompetent-men-become-leaders',
#    'why-conversational-programming-should-be-your-next-focus-area',
#    'why-mass-data-fragmentation-matters-compare-cloud']],
#  [8,
#   'intelligence',
#   ['intelligence',
#    'intelligence',
#    'intelligence',
#    'intelligence',
#    'intelligence',
#    'intelligence',
#    'intelligence',
#    'intelligence'],
#   'intelligence',
#   ['artificial-intelligence-describing-smells-ibm-research-quartz',
#    'how-to-leverage-artificial-intelligence-to-gain-business-advantage',
#    'artificial-intelligence-salaries-heading-skyward-machine-learning-memoirs-medium',
#    'china-military-rushing-use-artificial-intelligence-mit-technology-review',
#    'intelligence-officials-warn-climate-change-is-worldwide-threat-insideclimate-news',
#    'the-new-geopolitics-artificial-intelligence-world-economic-forum',
#    'maximizing-data-intelligence-compliant-automated-policy-enforcement',
#    'ai-ethics-artificial-intelligence-robots-society']],
#  [8,
#   'teaching',
#   ['learning',
#    'learning',
#    'learning',
#    'learning',
#    'graduate',
#    'learning',
#    'learning',
#    'learning'],
#   'teaching',
#   ['machine-learning-contributing-reproducibility-crisis-science-mit-technology-review',
#    'artificial-intelligence-salaries-heading-skyward-machine-learning-memoirs-medium',
#    'human-pose-machines-self-supervised-learning',
#    'ai-driven-learning-essential-digital-transformation',
#    'usc-graduate-nannearl-lekesia-brown-combines-tech-nonprofit-leadership-blacks-in-technology',
#    'the-five-levels-machine-learning-use-cases-allie-miller-medium',
#    'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet',
#    'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet']],
#  [9,
#   'learning',
#   ['learning',
#    'learning',
#    'learning',
#    'learning',
#    'learn',
#    'learning',
#    'learn',
#    'learning',
#    'learning'],
#   'learning',
#   ['machine-learning-contributing-reproducibility-crisis-science-mit-technology-review',
#    'artificial-intelligence-salaries-heading-skyward-machine-learning-memoirs-medium',
#    'human-pose-machines-self-supervised-learning',
#    'ai-driven-learning-essential-digital-transformation',
#    'pricing-algorithms-learn-collude-raise-prices-mit-technology-review',
#    'the-five-levels-machine-learning-use-cases-allie-miller-medium',
#    'what-cloud-computing-learn-good-bbq-infoworld',
#    'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet',
#    'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet']],
#  [11,
#   'ethics',
#   ['ethics',
#    'ethical',
#    'ethical',
#    'ethical',
#    'ethical',
#    'ethical',
#    'ethics',
#    'ethical',
#    'ethical',
#    'ethical',
#    'ethics'],
#   'ethics',
#   ['pop-culture-ai-and-ethics',
#    'google-created-responsible-innovation-team-check-ai-ethical-quartz',
#    'invest-ai-ethical-future-techcrunch',
#    'london-helsinki-collaborate-ethical-ai-data-smart-cities-world',
#    'google-completed-ethical-reviews-ai-projects-products-deals-venturebeat',
#    'council-post-the-top-three-considerations-for-designing-ethical-ai',
#    'highlights-transcript-zuckerberg-word-ethics-talk-techcrunch',
#    'the-folly-trolleys-ethical-challenges-autonomous-vehicles',
#    'the-folly-trolleys-ethical-challenges-autonomous-vehicles',
#    'invest-ai-ethical-future-techcrunch',
#    'ai-ethics-artificial-intelligence-robots-society']],
#  [14,
#   'science',
#   ['research',
#    'science',
#    'technology',
#    'science',
#    'technology',
#    'technology',
#    'science',
#    'research',
#    'technology',
#    'science',
#    'technology',
#    'technology',
#    'scientific',
#    'science'],
#   'science',
#   ['artificial-intelligence-describing-smells-ibm-research-quartz',
#    'machine-learning-contributing-reproducibility-crisis-science-mit-technology-review',
#    'machine-learning-contributing-reproducibility-crisis-science-mit-technology-review',
#    'introducing-world-data-management-platform-data-science-immuta',
#    'cloud-based-ai-technology-propels-cardiovascular-medicine-forward',
#    'china-military-rushing-use-artificial-intelligence-mit-technology-review',
#    'infosurhoy-latest-science-news-reports',
#    'this-algorithm-decodes-rat-squeaks-revolutionize-animal-research-youtube',
#    'usc-graduate-nannearl-lekesia-brown-combines-tech-nonprofit-leadership-blacks-in-technology',
#    'deliberate-data-science-medium',
#    'pricing-algorithms-learn-collude-raise-prices-mit-technology-review',
#    'anti-vaxx-propaganda-gone-viral-facebook-pinterest-cure-technology-the-guardian',
#    'towards-reconstructing-intelligible-speech-human-auditory-cortex-scientific-reports',
#    'we-re-women-science-we-re-scientists']],
#  [38,
#   'reason',
#   ['actually',
#    'why',
#    'need',
#    'know',
#    'why',
#    'what',
#    'what',
#    'not',
#    'should',
#    'explain',
#    'what',
#    'know',
#    'why',
#    'why',
#    'do',
#    'reasons',
#    'come',
#    'want',
#    'why',
#    'should',
#    'why',
#    'think',
#    'know',
#    'what',
#    'does',
#    'really',
#    'even',
#    'think',
#    'what',
#    'do',
#    'if',
#    'if',
#    'what',
#    'worry',
#    'that',
#    'actually',
#    'because',
#    'that'],
#   'reason',
#   ['facebook-clear-history-tool-actually-happen-it-time',
#    'why-mass-data-fragmentation-matters-compare-cloud',
#    'opinion-the-two-codes-your-kids-need-know-the-new-york-times',
#    'opinion-the-two-codes-your-kids-need-know-the-new-york-times',
#    'automating-creativity-why-short-talk-samim-youtube',
#    'what-happens-younger-workers-when-older-workers-don-retire',
#    'what-is-public-the-message-medium',
#    'mondaq-not-allowed-bad-crawler',
#    'should-robots-marketed-children-teenagers',
#    'could-counterfactuals-explain-algorithmic-decisions-without-opening-black-box-oxford-internet-institute',
#    'what-genetically-engineered-crispr-baby-business-insider',
#    'everything-know-nintendo-switch-business-insider',
#    'why-scientists-silent-gene-edited-babies',
#    'why-do-so-many-incompetent-men-become-leaders',
#    'why-do-so-many-incompetent-men-become-leaders',
#    'reasons-wireless-chargers-don-work-business-insider',
#    'come-on-the-hives-youtube',
#    'how-lost-legs-gained-want-inspiring-the-outline',
#    'why-conversational-programming-should-be-your-next-focus-area',
#    'why-conversational-programming-should-be-your-next-focus-area',
#    'why-mass-data-fragmentation-matters-compare-cloud',
#    'wealth-inequality-is-way-worse-than-you-think-and-tax-havens-play-big-role',
#    'containers-the-pros-cons-know-infoworld',
#    'what-does-augmented-workforce-really-look-like',
#    'what-does-augmented-workforce-really-look-like',
#    'what-does-augmented-workforce-really-look-like',
#    'even-iab-warned-adtech-risks-eu-privacy-rules-techcrunch',
#    'at-think-ibm-brings-ai-multicloud-confronts-formidable-challenges-siliconangle',
#    'what-to-do-if-you-ve-been-hacked-compare-cloud',
#    'what-to-do-if-you-ve-been-hacked-compare-cloud',
#    'what-to-do-if-you-ve-been-hacked-compare-cloud',
#    'buffett-apple-stock-price-if-cheaper-we-buying-it-business-insider',
#    'what-cloud-computing-learn-good-bbq-infoworld',
#    'worried-about-bias-ai-worry-about-humans-instead-center-data-innovation',
#    'new-job-insight-that-could-unlock-higher-salary-official-linkedin-blog',
#    'intel-neuro-guru-slams-deep-learning-it-actually-learning-zdnet',
#    'nike-android-app-is-bricking-shoes-because-that-headline-we-write-extremetech',
#    'nike-android-app-is-bricking-shoes-because-that-headline-we-write-extremetech']],
#  [63,
#   'industry',
#   ['business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'industry',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'companies',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business',
#    'business'],
#   'industry',
#   ['samsung-announces-new-galaxy-plus-phones-business-insider',
#    'facebook-cryptocurrency-whatsapp-launch-half-report-business-insider',
#    'israeli-moon-mission-spaceil-successfully-launches-spacex-rocket-business-insider',
#    'tesla-closing-stores-means-layoffs-retail-employees-business-insider',
#    'interesting-practical-amazon-purchases-business-insider',
#    'fitbit-sees-current-quarter-revenue-estimates-business-insider',
#    'google-announced-end-forced-arbitration-internal-matters-business-insider',
#    'purchases-wish-told-apartment-business-insider',
#    'apple-release-new-ipod-business-insider',
#    'travel-essentials-reduce-stress-away-suitcase-clear-membership-business-insider',
#    'data-new-oil-adam-schlosser-world-economic-forum-business-insider',
#    'billion-video-conferencing-company-zoom-aiming-april-ipo-business-insider',
#    'hbo-ceo-richard-plepler-leaving-nearly-years-business-insider',
#    'how-to-leverage-artificial-intelligence-to-gain-business-advantage',
#    'revealed-gambling-industry-targets-poor-people-ex-gamblers-society-the-guardian',
#    'open-letter-elon-musk-twitter-use-business-insider',
#    'watch-samsung-unveil-foldable-phone-galaxy-fold-business-insider',
#    'where-famous-tech-ceos-went-college-studied-list-business-insider',
#    'samsung-galaxy-specs-price-release-date-business-insider',
#    'samsung-galaxy-fold-massive-risk-buys-business-insider',
#    'health-fitness-startups-boom-business-insider',
#    'what-genetically-engineered-crispr-baby-business-insider',
#    'hound-labs-startup-founded-doctor-invents-marijuana-breathalyzer-business-insider',
#    'everything-know-nintendo-switch-business-insider',
#    'samsung-releases-video-galaxy-fold-business-insider',
#    'google-cloud-acquiring-alooma-help-migrate-data-cloud-business-insider',
#    'google-says-nest-microphone-never-supposed-secret-business-insider',
#    'samsung-teases-luxury-experience-buying-galaxy-fold-business-insider',
#    'samsung-galaxy-fold-release-date-price-specs-features-business-insider',
#    'quilty-weighted-blanket-review-it-helped-fall-asleep-minutes-business-insider',
#    'review-nokia-pureview-camera-smartphone-business-insider',
#    'reasons-wireless-chargers-don-work-business-insider',
#    'floating-home-withstand-category-hurricanes-photos-business-insider',
#    'new-apple-watch-include-sleep-tracking-feature-report-business-insider',
#    'hsbc-erwan-rambourg-forecasts-trouble-ahead-apple-china-business-insider',
#    'apple-dongle-problem-isn-getting-better-business-insider',
#    'tesla-suspends-orders-ahead-elon-musk-big-announcement-business-insider',
#    'retail-startups-shop-amazon-casper-leesa-mvmt-business-insider',
#    'cyber-security-threats-companies-face-digital-age',
#    'samsung-reveals-new-cheaper-galaxy-phone-business-insider',
#    'bill-gates-trampoline-room-million-medina-mansion-business-insider',
#    'apple-details-layoffs-self-driving-car-unit-filing-business-insider',
#    'huawei-mate-specifications-release-date-photos-price-business-insider',
#    'walmart-new-private-label-tech-accessories-line-motile-affordable-stylish-business-insider',
#    'lockly-secure-plus-smart-lock-review-fingerprint-reader-boosts-home-security-business-insider',
#    'tesla-closing-stores-adopting-online-only-model-business-insider',
#    'inventions-save-earth-business-insider',
#    'microsoft-vmware-partnership-won-amazon-happy-business-insider',
#    'watch-samsung-foldable-phone-galaxy-event-minutes-business-insider',
#    'peter-thiel-founders-fund-delivering-huge-returns-investors-business-insider',
#    'maxwell-investors-sue-block-tesla-acquisition-business-insider',
#    'executives-caught-florida-massage-parlor-prostitution-sting-business-insider',
#    'lyft-uber-let-drivers-stock-ipo-price-business-insider',
#    'buffett-apple-stock-price-if-cheaper-we-buying-it-business-insider',
#    'co-founder-ev-williams-leaving-twitter-board-business-insider',
#    'massdrop-vast-curved-gaming-monitor-review-perfect-option-business-insider',
#    'amtrak-train-stuck-hours-snow-hitting-tree-business-insider',
#    'photos-grand-canyon-history-year-anniversary-business-insider',
#    'wedbush-dan-ives-apple-acquire-hollywood-studio-lose-streaming-business-insider',
#    'microsoft-once-hated-clippy-cartoon-badge-honor-business-insider',
#    'researchers-lab-grown-thc-cbd-startups-blossoming-business-insider',
#    'watch-samsung-unveil-galaxy-business-insider',
#    'apple-can-compete-samsung-galaxy-fold-goldman-sachs-says-business-insider']]]

# %% [markdown]
# # Title vec (average words)

# %%
X = []
y = []
for title in texts:
    vec = None
    for word in title:
        if word in embeddings_index:
            if vec is None:
                vec = np.array([embeddings_index[word]])
            else:
                next_vec = embeddings_index[word]
                vec = np.concatenate((vec, np.array([next_vec])), axis=0) 
    
    if vec is not None:
        vec = vec.mean(axis=0)
        X.append(vec)
        y.append('-'.join(title))
        
print(len(y))
print(len(X))
# Out:
# 304
# 304

# %%
# keep those only a certain threhsold similar to other titles
disMatrix = compileMatrix(X)
len(disMatrix)
# Out:
# # comparelist: 304
# # n:  304
# 304

# %%
# for each emb, get number of other emb with less than a certain threshold
index_threshold = thresholdMatrix(disMatrix, threshold=0.15, num_threshold=2)
len(index_threshold)
# Out:
# # disMatrix: 304
# # n  304
# 5

# %%
print(index_threshold)
# Out:
# [3, 4, 5, 49, 50]

# %%
X_t = [ent for i, ent in enumerate(X) if i in index_threshold]
y_t = [ent for i, ent in enumerate(y) if i in index_threshold]
len(X_t)
# Out:
# 5

# %%
X_embedded = TSNE(n_components=2, perplexity=40, verbose=0).fit_transform(X_t)

# %%
plt.scatter(X_embedded[:, 0], X_embedded[:, 1])

# %%
fig = plotplotly(X_embedded, y, text=True)
py.iplot(fig, filename='hover-chart-basic')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~philsophie/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Title vec (title per word)

# %%
X = []
y = []
for title in texts:
    t = '-'.join(title)
    vec = None
    for word in title:
        if word in embeddings_index:
            X.append(embeddings_index[word])
            y.append(t)
    
print(len(X))
print(len(y))
# Out:
# 2331
# 2331

# %%
X_embedded = TSNE(n_components=2, perplexity=40, verbose=0).fit_transform(X)

# %%
plt.scatter(X_embedded[:, 0], X_embedded[:, 1])

# %%
fig = plotplotly(X_embedded, y)
py.iplot(fig, filename='hover-chart-basic')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~philsophie/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Test embedding combinations

# %%
embs = np.array([np.array([1,2]), np.array([3,4]), np.array([1,2]), np.array([3,4]), np.array([5,6]), np.array([0,0]), np.array([0,1])])
y = np.array(["this", "is", "this", "is", "fun", "indeed", "yay"])

# %%
print(embs)
# Out:
# [[1 2]
#  [3 4]
#  [1 2]
#  [3 4]
#  [5 6]
#  [0 0]
#  [0 1]]

# %%
print(embcomb(embs, y))
# Out:
# [[array([2., 3.]), array([1.66666667, 2.66666667]), array([2., 3.]), array([2.33333333, 3.33333333]), array([2., 3.]), array([3., 4.]), array([4., 5.]), array([2.66666667, 3.33333333]), array([2.5, 3. ]), array([1.66666667, 2.33333333]), array([0. , 0.5])], [{'is', 'this'}, {'is', 'this'}, {'is', 'this'}, {'is', 'this'}, {'is', 'this'}, {'is', 'this', 'fun'}, {'is', 'fun'}, {'is', 'indeed', 'fun'}, {'indeed', 'fun'}, {'yay', 'indeed', 'fun'}, {'yay', 'indeed'}]]

# %% [markdown]
# # Cluster titles based on similar terms (groups of words)

# %% [markdown]
# ### create a dictionary of term embeddings to terms in text form

# %%
emb_to_wordcomb = dict()
for title in texts:
    t = '-'.join(title)
    X = []
    y = []
    for word in title:
        # get word embeddings for title
        if word in embeddings_index:
            X.append(embeddings_index[word])
            y.append(word)
        
    # get word combinations of embeddings
    res = embcomb(np.array(X), y)
    if res:
        emb, wordcomb = res
        for i, e in enumerate(emb):
            e = hashdictkey(e)
            emb_to_wordcomb[e] = wordcomb[i]
        
print(len(emb_to_wordcomb))
# Out:
# 3464

# %%
# test eval of emb
for emb, words in emb_to_wordcomb.items():
    emb = unhashdictkey(emb)
    print(emb[0:5])
    print(words)
    break
# Out:
# [-0.02083    0.1872435  0.031435  -0.101271  -0.5947585]
# {'th', 'how'}

# %% [markdown]
# ### For each term embedding, compile a matrix of pairwise comparisons to determine similarity scores

# %%
# compute similarity matrix of emb
emb_list = list(emb_to_wordcomb.keys())
emb_list = [unhashdictkey(e) for e in emb_list]
len(emb_list)
# Out:
# 3464

# %%
disMatrix = compileMatrix(emb_list)
len(disMatrix)
# Out:
# # comparelist: 3464
# # n:  3464
# 3464

# %% [markdown]
# ### Threshold the distance matrix and keep only the term embeddings that are similar enough to enough other term embeddings

# %%
# for each emb, get number of other emb with less than a certain threshold
index_threshold = thresholdMatrix(disMatrix)
len(index_threshold)
# Out:
# # disMatrix: 3464
# # n  3464
# 237

# %%
# compile list of embeddings and word combinations based on indexes
X = []
y = []
#index_threshold = list(range(0,len(emb_list)))
for i in index_threshold:
    emb = emb_list[i]
    embhash = hashdictkey(emb)
    wordcomb = emb_to_wordcomb[embhash]
    wordcomb = '-'.join(list(wordcomb))
    X.append(emb)
    y.append(wordcomb)

print(len(X))
print(len(y))
# Out:
# 237
# 237

# %% [markdown]
# ### Reduce thresholded term embeddings to 2 dimensional

# %%
# I guess technically I don't need to reduce to 2 dim in order to cluster
X_embedded = TSNE(n_components=2, perplexity=40, verbose=0).fit_transform(X)
# Out:
# C:\Users\Sophie\Anaconda3\lib\site-packages\sklearn\neighbors\base.py:326: RuntimeWarning:
#
# invalid value encountered in sqrt

# %% [markdown]
# ### Cluster the resulting term embeddings and visualize

# %%
# clustering
#X_embedded = X
thresh = 1.5
clusters = hcluster.fclusterdata(X_embedded, thresh, criterion="distance")

# %%
print("# clusters:", len(set(clusters)))
# Out:
# # clusters: 28

# %%
# plotting
plt.scatter(*np.transpose(X_embedded), c=clusters)
plt.axis("equal")
title = "threshold: %f, number of clusters: %d" % (thresh, len(set(clusters)))
plt.title(title)
plt.show()

# %% [markdown]
# ### Convert to cluster of term embeddings, removing singleton clusters

# %%
clusters_dict = dict()
for i, clu in enumerate(clusters):
    if clu not in clusters_dict:
        clusters_dict[clu] = set()
    e = hashdictkey(X[i])
    clusters_dict[clu].add(e)

# %%
pop_items = []
for i, ent in clusters_dict.items():
    if len(ent) <= 1:
        pop_items.append(i)
    #print(len(ent))

# %%
print(len(clusters_dict))
for i in pop_items:
    clusters_dict.pop(i, None)
print(len(clusters_dict))
# Out:
# 28
# 24

# %% [markdown]
# ### For each term embedding cluster, check to see if any titles contain the term embedding. Create a cluster for titles. Remove singleton title clusters.

# %%
title_clusters = []
wordcomb_clusters = []
for key, clu in clusters_dict.items():
    print(key)
    title_clu = set()
    wordcomb_clu = set()
    for title in texts:
        t = '-'.join(title)
        X = []
        y = []
        for word in title:
            # get word embeddings for title
            if word in embeddings_index:
                X.append(embeddings_index[word])
                y.append(word)
        
        # get word combinations of embeddings
        res = embcomb(np.array(X), y)
        
        if res:
            emb, wordcomb = res
            for i, e in enumerate(emb):
                e = hashdictkey(e)
                if e in clu:
                    title_clu.add(t)
                    wordcomb_clu.add(hashdictkey(wordcomb[i]))
    
    if len(title_clu) > 1:
        title_clusters.append(title_clu)
        wordcomb_clusters.append(wordcomb_clu)
        
print("# title_clusters: ", len(title_clusters))
# Out:
# 19
# 27
# 3
# 28
# 13
# 10
# 4
# 6
# 8
# 12
# 7
# 16
# 11
# 1
# 25
# 2
# 17
# 24
# 26
# 5
# 18
# 15
# 9
# 14
# # title_clusters:  17

# %% [markdown]
# ### Inspect title clusters

# %%
for i, ts in enumerate(title_clusters):
    if len(ts) > 1:
        print(wordcomb_clusters[i])
        print(ts)
        print()
# Out:
# {"['you', 'than']", "['to', 'do', 'if']", "['happen', 'it', 'actually']", "['review', 'the', 'saturday']", "['why', 'do']", "['kids', 'your', 'need']", "['think', 'and']", "['if', 'you', 'do']", "['go', 'fast', 'how']", "['happens', 'what']", "['happen', 'it']", "['is', 'the']", "['to', 'leverage', 'how']", "['prime', 'israeli', 'minister']", "['come', 'on', 'the']", "['opinion', 'the', 'two']", "['tell', 'they', 'then']", "['look', 'really']", "['it', 'helped']", "['know', 'kids', 'need']", "['to', 'do', 'what']", "['kids', 'need']", "['guardian', 'the']", "['you', 'fast', 'how']", "['happen', 'actually']", "['to', 'what']", "['is', 'way']", "['review', 'it', 'helped']", "['the', 'know', 'need']", "['you', 'than', 'think']", "['the', 'new', 'york']", "['to', 'do']", "['the', 'news']", "['verge', 'the']", "['kids', 'your']", "['to', 'foster', 'how']", "['is', 'the', 'public']", "['allowed', 'not', 'bad']", "['short', 'why']", "['if', 'do']", "['internet', 'the', 'public']", "['know', 'need']", "['you', 'tell']", "['this', 'happen']", "['you', 'think']", "['the', 'know']", "['you', 'think', 'and']", "['considered', 'good', 'it']", "['is', 'public']", "['what', 'does']", "['the', 'know', 'new']", "['top', 'the', 'three']", "['tell', 'they']", "['considered', 'dangerous', 'it']", "['in', 'the']", "['you', 'tell', 'how']", "['many', 'do', 'so']", "['why', 'do', 'so']", "['you', 'give']", "['it', 'time']", "['brain', 'how']", "['it', 'man']", "['love', 'in', 'the']", "['you', 'how']", "['is', 'the', 'biggest']", "['is', 'change']", "['do', 'so']", "['look', 'like', 'really']", "['you', 'got']", "['washington', 'the', 'post']", "['next', 'the']", "['is', 'what']", "['everything', 'know']", "['good', 'it']", "['council', 'how', 'post']", "['you', 'than', 'worse']", "['than', 'worse', 'way']", "['is', 'what', 'public']", "['you', 'tell', 'cars']", "['to', 'how']", "['washington', 'the']", "['is', 'drive']", "['so', 'many']", "['you', 'the']", "['the', 'new']", "['you', 'the', 'new']", "['you', 'got', 'the']", "['must', 'it']", "['to', 'how', 'post']", "['the', 'secret']", "['must', 'it', 'boost']", "['the', 'two']", "['is', 'worse', 'way']", "['happen', 'it', 'time']"}
# {'hilde-lysiak-year-old-journalist-films-arizona-cop-threatening-the-washington-post', 'silicon-valley-oversight-democrats-probe-tech-privacy-practices-the-washington-post', 'how-to-leverage-artificial-intelligence-to-gain-business-advantage', 'google-organizers-join-lawmakers-forced-arbitration-fight-the-verge', 'medical-it-must-boost-its-immune-system-compare-cloud', 'audi-cars-tell-you-how-fast-go-catch-all-green-lights-wired', 'council-post-how-to-foster-positive-employee-experiences-to-drive-long-term-digital-transformations', 'ruyi-royal-love-in-the-palace-official-trailer-eng-sub-janine-chang-wallace-huo-zhou-xun-youtube', 'israeli-prime-minister-benjamin-netanyahu-indicted-corruption-charges', 'intelligence-officials-warn-climate-change-is-worldwide-threat-insideclimate-news', 'ai-won-relieve-misery-facebook-human-moderators-the-verge', 'china-uses-dna-track-its-people-with-help-american-expertise-the-new-york-times', 'america-professional-elite-wealthy-successful-miserable-the-new-york-times', 'why-do-so-many-incompetent-men-become-leaders', 'doordash-amazon-flex-tipping-policies-despite-instacart-outcry-the-verge', 'the-next-chinese-naval-threat-robot-warships', 'graham-spencer-programming-the-internet-public-lecture-youtube', 'the-secret-lives-facebook-moderators-america-the-verge', 'automating-creativity-why-short-talk-samim-youtube', 'come-on-the-hives-youtube', 'what-to-do-if-you-ve-been-hacked-compare-cloud', 'what-does-augmented-workforce-really-look-like', 'the-new-geopolitics-artificial-intelligence-world-economic-forum', 'what-is-public-the-message-medium', 'the-cybersecurity-your-phone-soon-recognize-based-walk-the-washington-post', 'you-give-apps-sensitive-personal-information-then-they-tell-facebook-wsj', 'facebook-clear-history-tool-actually-happen-it-time', 'robodebt-scheme-costs-government-recovers-australia-news-the-guardian', 'is-drive-by-sex-toy-hacking-wake-up-britain-internet-security-chi-onwurah-opinion-the-guardian', 'review-invisible-women-exposing-data-bias-world-designed-men-caroline-criado-perez-it-man-world-women-don-fit-saturday-review-the-times', 'opinion-the-two-codes-your-kids-need-know-the-new-york-times', 'confused-sound-mixing-vs-sound-editing-we-ve-got-you-the-new-york-times', 'quilty-weighted-blanket-review-it-helped-fall-asleep-minutes-business-insider', 'revealed-gambling-industry-targets-poor-people-ex-gamblers-society-the-guardian', 'wealth-inequality-is-way-worse-than-you-think-and-tax-havens-play-big-role', 'opinion-the-newest-jim-crow-the-new-york-times', 'justice-clarence-thomas-calls-reconsideration-landmark-libel-ruling-the-new-york-times', 'everything-know-nintendo-switch-business-insider', 'the-deadly-truth-world-built-men-stab-vests-car-crashes-life-style-the-guardian', 'how-brain-keeps-its-memories-right-order-wired', 'openai-built-text-generator-good-it-considered-dangerous-release-techcrunch', 'for-black-history-month-remarkable-women-men-we-overlooked-since-the-new-york-times', 'council-post-the-top-three-considerations-for-designing-ethical-ai', 'what-happens-younger-workers-when-older-workers-don-retire', 'anti-vaxx-propaganda-gone-viral-facebook-pinterest-cure-technology-the-guardian', 'this-happen-natural-world-insects-disappeared-world-economic-forum', 'discovery-cameras-built-airlines-seats-sparks-privacy-concerns-the-verge', 'mondaq-not-allowed-bad-crawler', 'chart-amazon-is-the-biggest-employer-tech-statista'}
#
# {"['insider', 'business', 'phones']", "['work', 'insider', 'business']", "['insider', 'business', 'stylish']", "['ipo', 'stock', 'price']", "['years', 'insider', 'business']", "['security', 'insider', 'business']", "['insider', 'business', 'acquisition']", "['use', 'insider', 'business']", "['insider', 'business', 'report']", "['features', 'insider', 'business']", "['insider', 'baby', 'business']", "['insider', 'business', 'employees']", "['insider', 'forum', 'business']", "['insider', 'business', 'photos']", "['insider', 'business', 'matters']", "['insider', 'business', 'secret']", "['insider', 'business', 'boom']", "['insider', 'business', 'model']", "['investors', 'insider', 'business']", "['insider', 'business', 'date']", "['apartment', 'insider', 'business']", "['insider', 'business', 'fold']", "['better', 'insider', 'business']", "['insider', 'business']", "['insider', 'price', 'business']", "['buys', 'insider', 'business']", "['purchases', 'insider', 'business']", "['insider', 'business', 'membership']", "['insider', 'business', 'china']", "['insider', 'business', 'phone']", "['insider', 'business', 'list']", "['insider', 'business', 'switch']", "['insider', 'estimates', 'business']", "['filing', 'insider', 'business']", "['insider', 'happy', 'business']", "['insider', 'it', 'business']", "['ipo', 'insider', 'business']", "['insider', 'earth', 'business']", "['insider', 'business', 'announcement']", "['cloud', 'insider', 'business']", "['price', 'business']"}
# {'tesla-closing-stores-means-layoffs-retail-employees-business-insider', 'watch-samsung-unveil-foldable-phone-galaxy-fold-business-insider', 'bill-gates-trampoline-room-million-medina-mansion-business-insider', 'microsoft-vmware-partnership-won-amazon-happy-business-insider', 'google-cloud-acquiring-alooma-help-migrate-data-cloud-business-insider', 'samsung-galaxy-fold-release-date-price-specs-features-business-insider', 'reasons-wireless-chargers-don-work-business-insider', 'co-founder-ev-williams-leaving-twitter-board-business-insider', 'watch-samsung-unveil-galaxy-business-insider', 'photos-grand-canyon-history-year-anniversary-business-insider', 'hbo-ceo-richard-plepler-leaving-nearly-years-business-insider', 'data-new-oil-adam-schlosser-world-economic-forum-business-insider', 'apple-details-layoffs-self-driving-car-unit-filing-business-insider', 'floating-home-withstand-category-hurricanes-photos-business-insider', 'inventions-save-earth-business-insider', 'researchers-lab-grown-thc-cbd-startups-blossoming-business-insider', 'apple-dongle-problem-isn-getting-better-business-insider', 'peter-thiel-founders-fund-delivering-huge-returns-investors-business-insider', 'lyft-uber-let-drivers-stock-ipo-price-business-insider', 'where-famous-tech-ceos-went-college-studied-list-business-insider', 'travel-essentials-reduce-stress-away-suitcase-clear-membership-business-insider', 'buffett-apple-stock-price-if-cheaper-we-buying-it-business-insider', 'massdrop-vast-curved-gaming-monitor-review-perfect-option-business-insider', 'wedbush-dan-ives-apple-acquire-hollywood-studio-lose-streaming-business-insider', 'maxwell-investors-sue-block-tesla-acquisition-business-insider', 'health-fitness-startups-boom-business-insider', 'retail-startups-shop-amazon-casper-leesa-mvmt-business-insider', 'samsung-galaxy-specs-price-release-date-business-insider', 'apple-release-new-ipod-business-insider', 'samsung-galaxy-fold-massive-risk-buys-business-insider', 'open-letter-elon-musk-twitter-use-business-insider', 'tesla-suspends-orders-ahead-elon-musk-big-announcement-business-insider', 'facebook-cryptocurrency-whatsapp-launch-half-report-business-insider', 'executives-caught-florida-massage-parlor-prostitution-sting-business-insider', 'hsbc-erwan-rambourg-forecasts-trouble-ahead-apple-china-business-insider', 'hound-labs-startup-founded-doctor-invents-marijuana-breathalyzer-business-insider', 'samsung-reveals-new-cheaper-galaxy-phone-business-insider', 'samsung-releases-video-galaxy-fold-business-insider', 'israeli-moon-mission-spaceil-successfully-launches-spacex-rocket-business-insider', 'samsung-teases-luxury-experience-buying-galaxy-fold-business-insider', 'purchases-wish-told-apartment-business-insider', 'fitbit-sees-current-quarter-revenue-estimates-business-insider', 'walmart-new-private-label-tech-accessories-line-motile-affordable-stylish-business-insider', 'microsoft-once-hated-clippy-cartoon-badge-honor-business-insider', 'what-genetically-engineered-crispr-baby-business-insider', 'interesting-practical-amazon-purchases-business-insider', 'huawei-mate-specifications-release-date-photos-price-business-insider', 'lockly-secure-plus-smart-lock-review-fingerprint-reader-boosts-home-security-business-insider', 'billion-video-conferencing-company-zoom-aiming-april-ipo-business-insider', 'quilty-weighted-blanket-review-it-helped-fall-asleep-minutes-business-insider', 'google-announced-end-forced-arbitration-internal-matters-business-insider', 'apple-can-compete-samsung-galaxy-fold-goldman-sachs-says-business-insider', 'google-says-nest-microphone-never-supposed-secret-business-insider', 'everything-know-nintendo-switch-business-insider', 'tesla-closing-stores-adopting-online-only-model-business-insider', 'watch-samsung-foldable-phone-galaxy-event-minutes-business-insider', 'review-nokia-pureview-camera-smartphone-business-insider', 'new-apple-watch-include-sleep-tracking-feature-report-business-insider', 'samsung-announces-new-galaxy-plus-phones-b ...
#
# {"['music', 'video']", "['youtube', 'videos', 'mom']", "['youtube', 'video']", "['official', 'youtube', 'video']", "['youtube', 'videos', 'kids']", "['official', 'trailer']", "['youtube', 'videos']"}
# {'ruyi-royal-love-in-the-palace-official-trailer-eng-sub-janine-chang-wallace-huo-zhou-xun-youtube', 'tolkien-official-trailer-fox-searchlight-youtube', 'mom-videos-youtube-kids-gave-children-instructions-suicide-cnn', 'rivers-nihil-the-silent-life-official-video-youtube', 'the-big-short-official-trailer-brad-pitt-christian-bale-drama-movie-hd-youtube', 'laid-back-white-horse-official-music-video-youtube'}
#
# {"['work', 'business']", "['better', 'business']", "['it', 'business', 'buying']", "['use', 'business']", "['business', 'announcement', 'big']", "['means', 'layoffs', 'stores']"}
# {'open-letter-elon-musk-twitter-use-business-insider', 'tesla-closing-stores-means-layoffs-retail-employees-business-insider', 'tesla-suspends-orders-ahead-elon-musk-big-announcement-business-insider', 'apple-dongle-problem-isn-getting-better-business-insider', 'buffett-apple-stock-price-if-cheaper-we-buying-it-business-insider', 'reasons-wireless-chargers-don-work-business-insider'}
#
# {"['billion', 'in']", "['years', 'nearly', 'business']", "['worth', 'now']", "['donations', 'billion', 'in']", "['worth', 'nearly', 'now']", "['nearly', 'as', 'much']", "['nearly', 'as']", "['years', 'nearly']", "['as', 'million', 'after']", "['billion', 'received']", "['years', 'nearly', 'leaving']", "['revenue', 'quarter', 'current']", "['after', 'funding', 'million']", "['worth', 'nearly', 'as']", "['years', 'business']"}
# {'hbo-ceo-richard-plepler-leaving-nearly-years-business-insider', 'fitbit-sees-current-quarter-revenue-estimates-business-insider', 'chart-harvard-received-billion-in-donations-last-year-statista', 'doordash-is-now-worth-nearly-as-much-as-grubhub-after-million-funding-infusion'}
#
# {"['google', 'says']", "['google', 'announced', 'end']", "['musk', 'elon', 'letter']", "['google', 'announced']"}
# {'google-announced-end-forced-arbitration-internal-matters-business-insider', 'google-says-nest-microphone-never-supposed-secret-business-insider', 'open-letter-elon-musk-twitter-use-business-insider'}
#
# {"['ai', 'could']", "['ai', 'thinks', 'could']", "['ai', 'thinks']", "['in', 'ai']", "['ai', 'and']", "['ai', 'in']"}
# {'pop-culture-ai-and-ethics', 'darpa-thinks-ai-could-help-troops-telepathically-control-machines-defense-one', 'women-stand-against-social-injustice-in-ai', 'surprise-ai-in'}
#
# {"['intelligence', 'artificial', 'leverage']", "['intelligence', 'artificial']", "['describing', 'intelligence', 'artificial']", "['use', 'intelligence', 'artificial']", "['to', 'intelligence', 'artificial']", "['word', 'contextual', 'representations']"}
# {'artificial-intelligence-describing-smells-ibm-research-quartz', 'china-military-rushing-use-artificial-intelligence-mit-technology-review', 'artificial-intelligence-salaries-heading-skyward-machine-learning-memoirs-medium', 'how-to-leverage-artificial-intelligence-to-gain-business-advantage', 'ai-ethics-artificial-intelligence-robots-society', 'contextual-word-representations-contextual-introduction', 'the-new-geopolitics-artificial-intelligence-world-economic-forum'}
#
# {"['release', 'date']", "['release', 'business', 'date']", "['release', 'price', 'specs']", "['release', 'price', 'date']", "['release', 'new', 'apple']"}
# {'samsung-galaxy-fold-release-date-price-specs-features-business-insider', 'huawei-mate-specifications-release-date-photos-price-business-insider', 'samsung-galaxy-specs-price-release-date-business-insider', 'apple-release-new-ipod-business-insider'}
#
# {"['world', 'forum', 'economic']", "['world', 'the']"}
# {'this-happen-natural-world-insects-disappeared-world-economic-forum', 'data-new-oil-adam-schlosser-world-economic-forum-business-insider', 'ai-transforming-the-world', 'the-new-geopolitics-artificial-intelligence-world-economic-forum'}
#
# {"['better', 'getting', 'business']", "['machine', 'learning']", "['better', 'getting']"}
# {'the-five-levels-machine-learning-use-cases-allie-miller-medium', 'apple-dongle-problem-isn-getting-better-business-insider', 'machine-learning-contributing-reproducibility-crisis-science-mit-technology-review', 'artificial-intelligence-salaries-heading-skyward-machine-learning-memoirs-medium'}
#
# {"['galaxy', 'fold']", "['galaxy', 'phone']", "['business', 'galaxy', 'fold']", "['fold', 'galaxy', 'phone']"}
# {'samsung-galaxy-fold-massive-risk-buys-business-insider', 'watch-samsung-unveil-foldable-phone-galaxy-fold-business-insider', 'apple-can-compete-samsung-galaxy-fold-goldman-sachs-says-business-insider', 'samsung-galaxy-fold-release-date-price-specs-features-business-insider', 'samsung-reveals-new-cheaper-galaxy-phone-business-insider', 'watch-samsung-foldable-phone-galaxy-event-minutes-business-insider', 'samsung-releases-video-galaxy-fold-business-insider', 'samsung-teases-luxury-experience-buying-galaxy-fold-business-insider'}
#
# {"['management', 'data', 'platform']", "['data', 'migration']", "['management', 'data']"}
# {'data-migration-data-portal', 'introducing-world-data-management-platform-data-science-immuta'}
#
# {"['women', 'we', 'men']", "['women', 'stand']", "['re', 'women', 'we']", "['become', 'men']", "['women', 'world', 'man']", "['women', 'world']", "['world', 'men', 'designed']"}
# {'review-invisible-women-exposing-data-bias-world-designed-men-caroline-criado-perez-it-man-world-women-don-fit-saturday-review-the-times', 'women-stand-against-social-injustice-in-ai', 'we-re-women-science-we-re-scientists', 'for-black-history-month-remarkable-women-men-we-overlooked-since-the-new-york-times', 'why-do-so-many-incompetent-men-become-leaders'}
#
# {"['cloud', 'issues', 'migration']", "['cloud', 'containers', 'computing']", "['cloud', 'the']"}
# {'the-cloud-enterprise-compatibility-edge-computing-containers-serverless-cloud-tech-news', 'five-cloud-migration-issues-you-shouldn-ignore-compare-cloud'}
#
# {"['specs', 'galaxy', 'samsung']", "['galaxy', 'samsung']"}
# {'samsung-galaxy-fold-massive-risk-buys-business-insider', 'apple-can-compete-samsung-galaxy-fold-goldman-sachs-says-business-insider', 'samsung-galaxy-specs-price-release-date-business-insider', 'samsung-galaxy-fold-release-date-price-specs-features-business-insider'}
#
# {"['future', 'ai', 'ethical']", "['ai', 'ethical']"}
# {'london-helsinki-collaborate-ethical-ai-data-smart-cities-world', 'google-created-responsible-innovation-team-check-ai-ethical-quartz', 'invest-ai-ethical-future-techcrunch', 'council-post-the-top-three-considerations-for-designing-ethical-ai'}

# %% [markdown]
# # Clusters

# %% [markdown]
# # Twitter Title vec (word comb)

# %%
# generate 3 clusters of each around 100 points and one orphan point
N=10
data = numpy.random.randn(3*N,2)
data
# Out:
# array([[ 1.38633287, -0.36906205],
#        [-1.01810207,  0.64189455],
#        [ 0.23915334,  0.96815477],
#        [-0.92326928, -0.43100763],
#        [ 1.04914793, -0.05927405],
#        [ 0.20357374,  1.06752123],
#        [-1.62169129,  0.09258646],
#        [ 0.0751854 ,  0.74952735],
#        [-0.34422571, -0.96195107],
#        [-1.44494336, -0.53821976],
#        [ 1.03047205,  0.3928194 ],
#        [-0.58541604, -1.95471536],
#        [-0.76849966,  0.72846697],
#        [ 0.5717663 , -0.30951834],
#        [ 0.7985133 , -0.47454796],
#        [ 0.30020059,  0.7842762 ],
#        [ 1.11441417,  0.02895118],
#        [ 0.09987074, -0.23087768],
#        [ 0.23683338, -1.8172031 ],
#        [ 0.06472395, -1.57093212],
#        [ 0.85246737,  2.4203319 ],
#        [ 0.77238542,  0.76019397],
#        [ 0.10600235, -1.20357168],
#        [-0.93689318,  1.53931605],
#        [ 2.63009459,  2.19410335],
#        [-0.01815774, -1.05922983],
#        [ 1.88365607,  1.70029421],
#        [ 1.86733115, -0.4687485 ],
#        [ 0.93030544,  0.54041984],
#        [-1.44947006,  0.1073681 ]])

# %% [raw]
# print(data)

# %%
data[:N] += 5
data[-N:] += 10
data[-1:] -= 20

# clustering
thresh = 1.5
clusters = hcluster.fclusterdata(data, thresh, criterion="distance")

# %%
all_texts = texts

# %%
texts = all_texts
len(texts)
# Out:
# 307

# %%
import random

random.shuffle(texts)
texts = texts[:200]

# %%
emb_to_wordcomb = dict()
for title in texts:
    t = '-'.join(title)
    X = []
    y = []
    for word in title:
        # get word embeddings for title
        if word in embeddings_index:
            X.append(embeddings_index[word])
            y.append(word)
        
    # get word combinations of embeddings
    res = embcomb(np.array(X), y, max_comb=3)
    if res:
        emb, wordcomb = res
        for i, e in enumerate(emb):
            e = hashdictkey(e)
            emb_to_wordcomb[e] = wordcomb[i]
        
print(len(emb_to_wordcomb))
# Out:
# 2367

# %%
# compute similar matrix of emb
emb_list = list(emb_to_wordcomb.keys())
emb_list = [unhashdictkey(e) for e in emb_list]
len(emb_list)
# Out:
# 2367

# %%
disMatrix = compileMatrix(emb_list)
len(disMatrix)
# Out:
# # comparelist: 2367
# # n:  2367
# 2367

# %%
# for each emb, get number of other emb with less than a certain threshold
index_threshold = thresholdMatrix(disMatrix, threshold=0.3, num_threshold=3)
len(index_threshold)
# Out:
# # disMatrix: 2367
# # n  2367
# 869

# %%
# compile list of embeddings and word combinations based on indexes
X = []
y = []
for i in index_threshold:
    emb = emb_list[i]
    embhash = hashdictkey(emb)
    wordcomb = emb_to_wordcomb[embhash]
    wordcomb = '-'.join(list(wordcomb))
    X.append(emb)
    y.append(wordcomb)

print(len(X))
print(len(y))
# Out:
# 869
# 869

# %%
X_embedded = TSNE(n_components=2, perplexity=40, verbose=0).fit_transform(X)

# %%
plt.scatter(X_embedded[:, 0], X_embedded[:, 1])

# %%
fig = plotplotly(X_embedded, y, text=False)
py.iplot(fig, filename='hover-chart-basic')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~philsophie/2.embed" height="525px" width="100%"></iframe>

# %%
for title1 in titles:
    for title2 in titles:
        # grab emb combinations of title1
        
        # grab emb combinations of title2
        
        # check if any are similar in matrix
        
            # if similar, put titles in a cluster... but then how will I continue adding to the cluster? compute the average and compare to avg of cluster?

# %% [markdown]
# # Gensim most similar

# %%
from gensim.models import word2vec

# %%
model = word2vec.Word2Vec(sentences, size=200)
sentences = word2vec.Text8Corpus('text8')

# %%
from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

glove_file = datapath("/home/sophie/AI-Values/glove.6B/glove.6B.300d.txt")
tmp_file = get_tmpfile("/home/sophie/AI-Values/glove.6B/glove.6B.300d_word2vec.txt")

_ = glove2word2vec(glove_file, tmp_file)
model = KeyedVectors.load_word2vec_format(tmp_file)

# %%
print(model.most_similar(['privacy']))
# Out:
# [('confidentiality', 0.5798313617706299), ('liberties', 0.5725791454315186), ('protections', 0.5712763667106628), ('protection', 0.4882546663284302), ('protect', 0.48595649003982544), ('protecting', 0.48228394985198975), ('freedom', 0.460526704788208), ('disclosure', 0.44946324825286865), ('safety', 0.44887790083885193), ('concerns', 0.446600079536438)]

# %%
print(model.most_similar(positive=['artificial', 'intelligence'], topn=3))
# Out:
# [('knowledge', 0.4611586332321167), ('information', 0.460480272769928), ('cia', 0.4384228587150574)]

# %%
print(model.most_similar(['artificial']))
# Out:
# [('synthetic', 0.49244236946105957), ('insemination', 0.47381332516670227), ('man-made', 0.45914873480796814), ('natural', 0.4262947142124176), ('sweeteners', 0.42168718576431274), ('artificially', 0.41367924213409424), ('implanted', 0.4032576084136963), ('manmade', 0.391124427318573), ('neural', 0.389220654964447), ('sweetener', 0.38666772842407227)]

# %%
print(model.most_similar(['artificial', 'intelligence']))
# Out:
# [('knowledge', 0.4611586332321167), ('information', 0.460480272769928), ('cia', 0.4384228587150574), ('methods', 0.4249553978443146), ('techniques', 0.4159538149833679), ('source', 0.41385820508003235), ('sophisticated', 0.4133008122444153), ('secret', 0.41233497858047485), ('using', 0.4104449450969696), ('sources', 0.40984243154525757)]

# %%
print(model.most_similar(['genealogy']))
# Out:
# [('genealogical', 0.6413923501968384), ('genealogies', 0.5469214916229248), ('heraldry', 0.4801636338233948), ('ancestry', 0.4725051522254944), ('lineage', 0.46874651312828064), ('ancestor', 0.43732717633247375), ('genealogist', 0.4359472990036011), ('folklore', 0.4338807463645935), ('origins', 0.4301758408546448), ('tracing', 0.41735735535621643)]

# %%
print(model.most_similar(['lineage']))
# Out:
# [('lineages', 0.7093613743782043), ('ancestor', 0.6329213380813599), ('descendant', 0.5997883081436157), ('ancestors', 0.5798022150993347), ('ancestry', 0.5490856170654297), ('descendants', 0.5397379398345947), ('origins', 0.5340539813041687), ('bloodline', 0.5154845714569092), ('patrilineal', 0.5056362152099609), ('paternal', 0.5042784214019775)]

# %%
print(model.most_similar(['resolve']))
# Out:
# [('resolving', 0.7659726142883301), ('resolved', 0.7524896264076233), ('solve', 0.7424017786979675), ('dispute', 0.6705842018127441), ('disputes', 0.6687039136886597), ('impasse', 0.6213710308074951), ('determination', 0.5951550006866455), ('differences', 0.5740435123443604), ('issue', 0.5731443166732788), ('disagreements', 0.5667888522148132)]

# %%
print(model.most_similar(['conflict']))
# Out:
# [('conflicts', 0.8084380626678467), ('war', 0.6729421615600586), ('strife', 0.6499618291854858), ('bloodshed', 0.6260631084442139), ('violence', 0.6070914268493652), ('hostilities', 0.6060783267021179), ('tensions', 0.5968263745307922), ('confrontation', 0.5958433151245117), ('crisis', 0.594000518321991), ('fighting', 0.5881012678146362)]
